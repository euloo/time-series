# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import pandas as pd
import datetime

from statsmodels.graphics.tsaplots import plot_acf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM,CuDNNLSTM
from keras.layers import Dropout
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.utils import plot_model

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms

# %matplotlib inline
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using TensorFlow backend.

# %%
MODELS_DIR='j_models'

# %%
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")
print(device)
# Out:
# cpu

# %%
torch.manual_seed(42)

# %%
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
np.random.seed(42)

# %%
file = h5py.File('Fort.mat', 'r')
data = file.get('Fort')
Fort = np.array(data)

# %%
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.show()

# %%
def split_signal(inpt, length, batch_size, sclr, show=False):
    f = sclr.fit_transform(inpt)
    f_tr = f[:batch_size]
    f_test = f[batch_size-length:]
    if show:
        plt.figure(figsize = (10, 5))
        plt.plot(f, 'k')
        plt.plot(np.r_[:batch_size],f_tr, 'b')
        plt.plot(np.r_[batch_size-length:len(inpt)],f_test, 'r')
        plt.show()

        print(f_tr.shape[0], f_test.shape[0])
    return f_tr, f_test

# %%
def get_ts(source, length, batch_size):
    data_gen = TimeseriesGenerator(source, source,
                                 length=length, sampling_rate=1,
                                 batch_size=batch_size)
    x, yy = data_gen[0]
    xx=np.reshape(x, (x.shape[0], 1, x.shape[1]))
#     print(xx.shape)
#     print(yy.shape)
    return torch.Tensor(xx), yy

# %%
class TSDataSet(torch.utils.data.Dataset):
    def __init__(self, inputs, targets):
        self.inputs = inputs
        self.targets = targets
         
    def __len__(self):
        return self.inputs.shape[0]
    
    def __getitem__(self, i):
        
        return torch.from_numpy(self.inputs[i]).unsqueeze(-1).float(), torch.Tensor([self.targets[i]]).squeeze().float()

# %%
def get_dataset(inpt, length):
    F_t=F_tr.ravel().astype(np.float)
    F_data=np.array([[F_t[i:i+length+1][:-1],F_t[i:i+length+1][-1]] for i in range(len(F_tr)-length)])
    return TSDataSet(F_data[:,0],F_data[:,1])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
F_tr, F_test = split_signal(Fort, 6, 150, scaler, True)
# Out:
# 150 30

# %%
train_xx, train_yy = get_ts(F_tr, 6, 150)

# %%
test_xx, test_yy = get_ts(F_test, 6, 150)

# %%
train_set=get_dataset(F_tr,6)

# %%
batch_size=1
train_loader = torch.utils.data.DataLoader(train_set, 
                                           batch_size=batch_size, 
                                           shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self, batch_size, input_dim, hidden_dim, drpout=None):
        super(Net, self).__init__()
        self.batch_size = batch_size
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.drpout = drpout
        
        if not self.drpout:
            self.lstm1 = nn.LSTM(self.input_dim, self.hidden_dim) 
            self.fc1 = nn.Linear(self.hidden_dim, 1)
        else:
            self.lstm1 = nn.LSTM(self.input_dim, self.hidden_dim)
            self.lstm2 = nn.LSTM(self.hidden_dim, self.hidden_dim)
            self.lstm3 = nn.LSTM(self.hidden_dim, self.hidden_dim)
            self.fc1 = nn.Linear(self.hidden_dim, 1)
            
            self.dropout = nn.Dropout(0.5) 

    def init_hidden(self):
        return (torch.zeros(2, self.batch_size, self.hidden_dim),
                torch.zeros(2, self.batch_size, self.hidden_dim))

    def forward(self, x): 
        if not self.drpout:
            x, self.hidden = self.lstm1(x.view(len(x), self.batch_size, -1))
            x = self.fc1(x[-1].view(self.batch_size, -1))
        else:
            x, self.hidden = self.lstm1(x.view(len(x), self.batch_size, -1))
            x = self.dropout(x)
            x, self.hidden = self.lstm2(x.view(len(x), self.batch_size, -1))
            x = self.dropout(x)
            x, self.hidden = self.lstm3(x.view(len(x), self.batch_size, -1))
            x = self.fc1(x[-1].view(self.batch_size, -1))
        
        return x.view(-1)

# %%
net = Net(batch_size, 6, 20, 0.2).to(device)
net
# Out:
# Net(
#   (lstm1): LSTM(6, 20)
#   (lstm2): LSTM(20, 20)
#   (lstm3): LSTM(20, 20)
#   (fc1): Linear(in_features=20, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
criterion = nn.MSELoss().to(device)
optimizer = torch.optim.Adam(net.parameters())

# %%
for epoch in range(100):   
    net.hidden = net.init_hidden()
    for i, data in enumerate(train_loader):

        inputs, labels = data[0].to(device), data[1].to(device)

        optimizer.zero_grad()

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    if (epoch + 1) % 10 == 0:
        print('epoch %d, training loss: %.3f' %
          (epoch+1, loss.item()))

print('finish')
# Out:
# epoch 10, training loss: 0.036
# epoch 20, training loss: 0.019
# epoch 30, training loss: 0.070
# epoch 40, training loss: 0.001
# epoch 50, training loss: 0.017
# epoch 60, training loss: 0.000
# epoch 70, training loss: 0.021
# epoch 80, training loss: 0.127
# epoch 90, training loss: 0.072
# epoch 100, training loss: 0.009
# finish

# %%
pred_train=[]
for i in range(len(train_xx)):
    out=net(train_xx[i].unsqueeze(-1).to(device))
    pred_train.append(out.detach().cpu().item())
pred_train=np.array(pred_train)
trainPredict = scaler.inverse_transform(pred_train.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[6:150],trainPredict, 'b')
plt.show()

# %%
pred_test=[]
for i in range(len(test_xx)):
    out=net(test_xx[i].unsqueeze(-1).to(device))
    pred_test.append(out.detach().cpu().item())
pred_test=np.array(pred_test)
testPredict = scaler.inverse_transform(pred_test.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[150:174],testPredict, 'b')
plt.show()

# %%
pred_forecast=[]
inp=test_xx[-1].unsqueeze(-1).to(device)
for i in range(24):
    out=net(inp)
    out=out.detach().cpu().item()
    pred_forecast.append(out)
    inp[0,0,0]=out
    inp=inp.roll(-1)
pred_forecast=np.array(pred_forecast)
forecastPredict = scaler.inverse_transform(pred_forecast.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[len(Fort)-1:len(Fort)+24-1],forecastPredict, 'b')
plt.show()

# %%
def train(inpt, epchs, f_msk, **kwargs):
    start=datetime.datetime.now()
    
    delay=kwargs['delay']
    neuron=kwargs['neuron']
    btch_sz=kwargs['btch_sz']
    
    scaler = MinMaxScaler(feature_range=(0, 1))
    F_tr, F_test = split_signal(inpt, delay, btch_sz, scaler)
    train_xx, train_yy = get_ts(F_tr, delay, btch_sz)
    test_xx, test_yy = get_ts(F_test, delay, btch_sz)
    train_set=get_dataset(F_tr,delay)
    batch_size=1
    train_loader = torch.utils.data.DataLoader(train_set, 
                                               batch_size=batch_size, 
                                               shuffle=True)

    net = Net(batch_size, delay, neuron, kwargs.get('drpout')).to(device)



    criterion = nn.MSELoss().to(device)
    optimizer = torch.optim.Adam(net.parameters())

    train_mse=[]
    test_mse=[]
    
    for epoch in range(epchs):
        net.train()
        net.hidden = net.init_hidden()
        for i, data in enumerate(train_loader):

            inputs, labels = data[0].to(device), data[1].to(device)

            optimizer.zero_grad()

            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

#         if (epoch + 1) % 10 == 0:
#             print('epoch %d, training loss: %.3f' %
#               (epoch+1, loss.item()))

        net.eval()

        pred_train=[]
        for i in range(len(train_xx)):
            out=net(train_xx[i].unsqueeze(-1).to(device))
            pred_train.append(out.detach().cpu().item())
        pred_train=np.array(pred_train)

        pred_test=[]
        for i in range(len(test_xx)):
            out=net(test_xx[i].unsqueeze(-1).to(device))
            pred_test.append(out.detach().cpu().item())
        pred_test=np.array(pred_test)

        train_mse.append(mean_squared_error(train_yy,pred_train))
        test_mse.append(mean_squared_error(test_yy,pred_test))

    
    state = {
        'state': net.state_dict(),
        'train_mse': train_mse,
        'test_mse': test_mse
    }    
    torch.save(state, '{}_{}.t7'.format(f_msk, '_'.join([str(kwargs[k]) for k in kwargs])))  

    end=datetime.datetime.now()-start

    print('{} {} train_mse={:.3f} test_mse={:.3f}'.format(end, ' '.join(['{}={}'.format(k, kwargs[k]) for k in kwargs]), train_mse[-1], test_mse[-1]))
    
    return train_mse[-1], test_mse[-1], end

# %% [markdown]
# # Training

# %%
delays=[1,2,3,6,12]
neurons=[20,25,30,35,40,45,50]
batch_sizes=[100,125,150]
dropouts=[0.1,0.2,0.3]

# %%
epochs=100
file_mask=MODELS_DIR+'\\simple_fort_model'
simple_fort_model_result=pd.DataFrame()

# %%
for delay in delays:
    for neuron in neurons:
        for btch_sz in batch_sizes:
            train_mse, test_mse, end=train(Fort, epochs, file_mask, delay=delay, neuron=neuron, btch_sz=btch_sz)
            simple_fort_model_result=simple_fort_model_result.append([[delay, neuron, btch_sz, train_mse, test_mse, end]], ignore_index=True)
simple_fort_model_result.columns=['delay', 'neuron','btch_sz', 'train_mse', 'test_mse', 'time']
simple_fort_model_result=simple_fort_model_result.sort_values(['test_mse'])
simple_fort_model_result.to_excel('{}_result.xlsx'.format(file_mask), index=None)
# Out:
# 0:00:20.932040 delay=1 neuron=20 btch_sz=100 train_mse=0.025 test_mse=0.020
# 0:00:20.840092 delay=1 neuron=20 btch_sz=125 train_mse=0.026 test_mse=0.016
# 0:00:20.892062 delay=1 neuron=20 btch_sz=150 train_mse=0.023 test_mse=0.020
# 0:00:21.005996 delay=1 neuron=25 btch_sz=100 train_mse=0.025 test_mse=0.019
# 0:00:21.094947 delay=1 neuron=25 btch_sz=125 train_mse=0.025 test_mse=0.018
# 0:00:21.023988 delay=1 neuron=25 btch_sz=150 train_mse=0.024 test_mse=0.022
# 0:00:21.211879 delay=1 neuron=30 btch_sz=100 train_mse=0.025 test_mse=0.024
# 0:00:21.201885 delay=1 neuron=30 btch_sz=125 train_mse=0.026 test_mse=0.016
# 0:00:21.290835 delay=1 neuron=30 btch_sz=150 train_mse=0.023 test_mse=0.019
# 0:00:21.767562 delay=1 neuron=35 btch_sz=100 train_mse=0.025 test_mse=0.025
# 0:00:21.737579 delay=1 neuron=35 btch_sz=125 train_mse=0.027 test_mse=0.015
# 0:00:21.768562 delay=1 neuron=35 btch_sz=150 train_mse=0.023 test_mse=0.020
# 0:00:22.102371 delay=1 neuron=40 btch_sz=100 train_mse=0.025 test_mse=0.022
# 0:00:21.930472 delay=1 neuron=40 btch_sz=125 train_mse=0.025 test_mse=0.020
# 0:00:22.026415 delay=1 neuron=40 btch_sz=150 train_mse=0.024 test_mse=0.024
# 0:00:22.286266 delay=1 neuron=45 btch_sz=100 train_mse=0.027 test_mse=0.017
# 0:00:22.224302 delay=1 neuron=45 btch_sz=125 train_mse=0.025 test_mse=0.017
# 0:00:22.286266 delay=1 neuron=45 btch_sz=150 train_mse=0.024 test_mse=0.021
# 0:00:22.660053 delay=1 neuron=50 btch_sz=100 train_mse=0.026 test_mse=0.018
# 0:00:22.775985 delay=1 neuron=50 btch_sz=125 train_mse=0.025 test_mse=0.020
# 0:00:22.839943 delay=1 neuron=50 btch_sz=150 train_mse=0.024 test_mse=0.024
# 0:00:20.952028 delay=2 neuron=20 btch_sz=100 train_mse=0.025 test_mse=0.021
# 0:00:20.709166 delay=2 neuron=20 btch_sz=125 train_mse=0.026 test_mse=0.016
# 0:00:20.624214 delay=2 neuron=20 btch_sz=150 train_mse=0.023 test_mse=0.018
# 0:00:20.910051 delay=2 neuron=25 btch_sz=100 train_mse=0.025 test_mse=0.022
# 0:00:20.952027 delay=2 neuron=25 btch_sz=125 train_mse=0.026 test_mse=0.027
# 0:00:20.990006 delay=2 neuron=25 btch_sz=150 train_mse=0.025 test_mse=0.015
# 0:00:21.050971 delay=2 neuron=30 btch_sz=100 train_mse=0.029 test_mse=0.016
# 0:00:21.026986 delay=2 neuron=30 btch_sz=125 train_mse=0.025 test_mse=0.019
# 0:00:21.036980 delay=2 neuron=30 btch_sz=150 train_mse=0.023 test_mse=0.019
# 0:00:21.871502 delay=2 neuron=35 btch_sz=100 train_mse=0.025 test_mse=0.020
# 0:00:21.901485 delay=2 neuron=35 btch_sz=125 train_mse=0.027 test_mse=0.015
# 0:00:21.794547 delay=2 neuron=35 btch_sz=150 train_mse=0.024 test_mse=0.025
# 0:00:22.000429 delay=2 neuron=40 btch_sz=100 train_mse=0.026 test_mse=0.019
# 0:00:21.999429 delay=2 neuron=40 btch_sz=125 train_mse=0.024 test_mse=0.021
# 0:00:21.962448 delay=2 neuron=40 btch_sz=150 train_mse=0.023 test_mse=0.022
# 0:00:22.426186 delay=2 neuron=45 btch_sz=100 train_mse=0.026 test_mse=0.019
# 0:00:22.293261 delay=2 neuron=45 btch_sz=125 train_mse=0.026 test_mse=0.016
# 0:00:22.319246 delay=2 neuron=45 btch_sz=150 train_mse=0.023 test_mse=0.019
# 0:00:22.615078 delay=2 neuron=50 btch_sz=100 train_mse=0.025 test_mse=0.021
# 0:00:22.787978 delay=2 neuron=50 btch_sz=125 train_mse=0.025 test_mse=0.016
# 0:00:22.722016 delay=2 neuron=50 btch_sz=150 train_mse=0.023 test_mse=0.020
# 0:00:20.693175 delay=3 neuron=20 btch_sz=100 train_mse=0.027 test_mse=0.017
# 0:00:20.616220 delay=3 neuron=20 btch_sz=125 train_mse=0.025 test_mse=0.018
# 0:00:20.562250 delay=3 neuron=20 btch_sz=150 train_mse=0.024 test_mse=0.022
# 0:00:20.838093 delay=3 neuron=25 btch_sz=100 train_mse=0.025 test_mse=0.020
# 0:00:20.750143 delay=3 neuron=25 btch_sz=125 train_mse=0.025 test_mse=0.018
# 0:00:20.814107 delay=3 neuron=25 btch_sz=150 train_mse=0.023 test_mse=0.019
# 0:00:20.965021 delay=3 neuron=30 btch_sz=100 train_mse=0.028 test_mse=0.017
# 0:00:20.936037 delay=3 neuron=30 btch_sz=125 train_mse=0.025 test_mse=0.016
# 0:00:20.939035 delay=3 neuron=30 btch_sz=150 train_mse=0.023 test_mse=0.018
# 0:00:21.677614 delay=3 neuron=35 btch_sz=100 train_mse=0.026 test_mse=0.018
# 0:00:21.696602 delay=3 neuron=35 btch_sz=125 train_mse=0.025 test_mse=0.016
# 0:00:21.646632 delay=3 neuron=35 btch_sz=150 train_mse=0.025 test_mse=0.015
# 0:00:22.080383 delay=3 neuron=40 btch_sz=100 train_mse=0.026 test_mse=0.025
# 0:00:21.929470 delay=3 neuron=40 btch_sz=125 train_mse=0.025 test_mse=0.016
# 0:00:21.977442 delay=3 neuron=40 btch_sz=150 train_mse=0.025 test_mse=0.015
# 0:00:22.136351 delay=3 neuron=45 btch_sz=100 train_mse=0.026 test_mse=0.018
# 0:00:22.217304 delay=3 neuron=45 btch_sz=125 train_mse=0.025 test_mse=0.018
# 0:00:22.242291 delay=3 neuron=45 btch_sz=150 train_mse=0.023 test_mse=0.020
# 0:00:22.521131 delay=3 neuron=50 btch_sz=100 train_mse=0.025 test_mse=0.020
# 0:00:22.540121 delay=3 neuron=50 btch_sz=125 train_mse=0.025 test_mse=0.018
# 0:00:22.643062 delay=3 neuron=50 btch_sz=150 train_mse=0.025 test_mse=0.015
# 0:00:20.691177 delay=6 neuron=20 btch_sz=100 train_mse=0.021 test_mse=0.024
# 0:00:20.514277 delay=6 neuron=20 btch_sz=125 train_mse=0.021 test_mse=0.018
# 0:00:20.264421 delay=6 neuron=20 btch_sz=150 train_mse=0.020 test_mse=0.018
# 0:00:20.383353 delay=6 neuron=25 btch_sz=100 train_mse=0.020 test_mse=0.021
# 0:00:20.333381 delay=6 neuron=25 btch_sz=125 train_mse=0.021 test_mse=0.020
# 0:00:20.359367 delay=6 neuron=25 btch_sz=150 train_mse=0.020 test_mse=0.022
# 0:00:20.688177 delay=6 neuron=30 btch_sz=100 train_mse=0.024 test_mse=0.017
# 0:00:20.671187 delay=6 neuron=30 btch_sz=125 train_mse=0.021 test_mse=0.018
# 0:00:20.559253 delay=6 neuron=30 btch_sz=150 train_mse=0.020 test_mse=0.020
# 0:00:21.251856 delay=6 neuron=35 btch_sz=100 train_mse=0.023 test_mse=0.017
# 0:00:21.303828 delay=6 neuron=35 btch_sz=125 train_mse=0.022 test_mse=0.017
# 0:00:21.302828 delay=6 neuron=35 btch_sz=150 train_mse=0.020 test_mse=0.025
# 0:00:21.554683 delay=6 neuron=40 btch_sz=100 train_mse=0.019 test_mse=0.023
# 0:00:21.536693 delay=6 neuron=40 btch_sz=125 train_mse=0.020 test_mse=0.023
# 0:00:21.517704 delay=6 neuron=40 btch_sz=150 train_mse=0.021 test_mse=0.032
# 0:00:21.843520 delay=6 neuron=45 btch_sz=100 train_mse=0.023 test_mse=0.016
# 0:00:21.797545 delay=6 neuron=45 btch_sz=125 train_mse=0.020 test_mse=0.023
# 0:00:21.860509 delay=6 neuron=45 btch_sz=150 train_mse=0.020 test_mse=0.029
# 0:00:22.160337 delay=6 neuron=50 btch_sz=100 train_mse=0.020 test_mse=0.026
# 0:00:22.167333 delay=6 neuron=50 btch_sz=125 train_mse=0.022 test_mse=0.017
# 0:00:22.322245 delay=6 neuron=50 btch_sz=150 train_mse=0.020 test_mse=0.027
# 0:00:19.470874 delay=12 neuron=20 btch_sz=100 train_mse=0.009 test_mse=0.003
# 0:00:19.626785 delay=12 neuron=20 btch_sz=125 train_mse=0.007 test_mse=0.003
# 0:00:19.759708 delay=12 neuron=20 btch_sz=150 train_mse=0.006 test_mse=0.003
# 0:00:19.932610 delay=12 neuron=25 btch_sz=100 train_mse=0.007 test_mse=0.003
# 0:00:19.616790 delay=12 neuron=25 btch_sz=125 train_mse=0.006 test_mse=0.003
# 0:00:19.675757 delay=12 neuron=25 btch_sz=150 train_mse=0.006 test_mse=0.003
# 0:00:19.795688 delay=12 neuron=30 btch_sz=100 train_mse=0.007 test_mse=0.003
# 0:00:19.843661 delay=12 neuron=30 btch_sz=125 train_mse=0.008 test_mse=0.005
# 0:00:19.863649 delay=12 neuron=30 btch_sz=150 train_mse=0.006 test_mse=0.003
# 0:00:20.585237 delay=12 neuron=35 btch_sz=100 train_mse=0.009 test_mse=0.004
# 0:00:20.506281 delay=12 neuron=35 btch_sz=125 train_mse=0.009 test_mse=0.005
# 0:00:20.524272 delay=12 neuron=35 btch_sz=150 train_mse=0.006 test_mse=0.003
# 0:00:20.773130 delay=12 neuron=40 btch_sz=100 train_mse=0.007 test_mse=0.003
# 0:00:20.775130 delay=12 neuron=40 btch_sz=125 train_mse=0.006 test_mse=0.003
# 0:00:21.121931 delay=12 neuron=40 btch_sz=150 train_mse=0.006 test_mse=0.002
# 0:00:21.158910 delay=12 neuron=45 btch_sz=100 train_mse=0.007 test_mse=0.003
# 0:00:21.074957 delay=12 neuron=45 btch_sz=125 train_mse=0.006 test_mse=0.003
# 0:00:21.073959 delay=12 neuron=45 btch_sz=150 train_mse=0.005 test_mse=0.003
# 0:00:21.516706 delay=12 neuron=50 btch_sz=100 train_mse=0.009 test_mse=0.004
# 0:00:21.436752 delay=12 neuron=50 btch_sz=125 train_mse=0.006 test_mse=0.003
# 0:00:21.478726 delay=12 neuron=50 btch_sz=150 train_mse=0.006 test_mse=0.003

# %%
epochs=100
file_mask=MODELS_DIR+'\\complex_fort_model'
complex_fort_model_result=pd.DataFrame()

# %%
for delay in delays:
    for neuron in neurons:
        for btch_sz in batch_sizes:
            for drpout in dropouts:
                train_mse, test_mse, end=train(Fort, epochs, file_mask, delay=delay, neuron=neuron, btch_sz=btch_sz, drpout=drpout)
                complex_fort_model_result=complex_fort_model_result.append([[delay, neuron, btch_sz, drpout, train_mse, test_mse, end]], ignore_index=True)
complex_fort_model_result.columns=['delay', 'neuron','btch_sz', 'drpout', 'train_mse', 'test_mse', 'time']
complex_fort_model_result=complex_fort_model_result.sort_values(['test_mse'])
complex_fort_model_result.to_excel('{}_result.xlsx'.format(file_mask), index=None)
# Out:
# 0:00:49.717593 delay=1 neuron=20 btch_sz=100 drpout=0.1 train_mse=0.025 test_mse=0.023
# 0:00:49.734583 delay=1 neuron=20 btch_sz=100 drpout=0.2 train_mse=0.026 test_mse=0.020
# 0:00:50.440179 delay=1 neuron=20 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.020
# 0:00:49.863509 delay=1 neuron=20 btch_sz=125 drpout=0.1 train_mse=0.026 test_mse=0.027
# 0:00:49.932470 delay=1 neuron=20 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.024
# 0:00:49.752572 delay=1 neuron=20 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.022
# 0:00:49.936468 delay=1 neuron=20 btch_sz=150 drpout=0.1 train_mse=0.025 test_mse=0.017
# 0:00:50.047403 delay=1 neuron=20 btch_sz=150 drpout=0.2 train_mse=0.025 test_mse=0.018
# 0:00:49.979442 delay=1 neuron=20 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.023
# 0:00:50.721018 delay=1 neuron=25 btch_sz=100 drpout=0.1 train_mse=0.026 test_mse=0.021
# 0:00:50.555113 delay=1 neuron=25 btch_sz=100 drpout=0.2 train_mse=0.025 test_mse=0.022
# 0:00:50.667049 delay=1 neuron=25 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.029
# 0:00:50.516135 delay=1 neuron=25 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.018
# 0:00:50.617078 delay=1 neuron=25 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.020
# 0:00:50.624074 delay=1 neuron=25 btch_sz=125 drpout=0.3 train_mse=0.027 test_mse=0.016
# 0:00:50.881926 delay=1 neuron=25 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.023
# 0:00:50.825960 delay=1 neuron=25 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.017
# 0:00:50.718021 delay=1 neuron=25 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.020
# 0:00:51.316678 delay=1 neuron=30 btch_sz=100 drpout=0.1 train_mse=0.025 test_mse=0.024
# 0:00:51.659482 delay=1 neuron=30 btch_sz=100 drpout=0.2 train_mse=0.027 test_mse=0.019
# 0:00:51.336667 delay=1 neuron=30 btch_sz=100 drpout=0.3 train_mse=0.025 test_mse=0.025
# 0:00:51.543550 delay=1 neuron=30 btch_sz=125 drpout=0.1 train_mse=0.026 test_mse=0.029
# 0:00:51.412624 delay=1 neuron=30 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.023
# 0:00:51.460596 delay=1 neuron=30 btch_sz=125 drpout=0.3 train_mse=0.028 test_mse=0.015
# 0:00:51.522561 delay=1 neuron=30 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.022
# 0:00:51.838381 delay=1 neuron=30 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.020
# 0:00:51.895348 delay=1 neuron=30 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.020
# 0:00:54.521848 delay=1 neuron=35 btch_sz=100 drpout=0.1 train_mse=0.025 test_mse=0.021
# 0:00:53.837238 delay=1 neuron=35 btch_sz=100 drpout=0.2 train_mse=0.025 test_mse=0.022
# 0:00:53.746289 delay=1 neuron=35 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.020
# 0:00:53.660341 delay=1 neuron=35 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.021
# 0:00:53.748289 delay=1 neuron=35 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.021
# 0:00:55.182469 delay=1 neuron=35 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.021
# 0:00:54.093093 delay=1 neuron=35 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.023
# 0:00:54.136068 delay=1 neuron=35 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.021
# 0:00:53.995149 delay=1 neuron=35 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.020
# 0:00:54.916622 delay=1 neuron=40 btch_sz=100 drpout=0.1 train_mse=0.026 test_mse=0.021
# 0:00:54.900631 delay=1 neuron=40 btch_sz=100 drpout=0.2 train_mse=0.025 test_mse=0.021
# 0:00:55.025560 delay=1 neuron=40 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.020
# 0:00:54.991579 delay=1 neuron=40 btch_sz=125 drpout=0.1 train_mse=0.028 test_mse=0.016
# 0:00:54.989581 delay=1 neuron=40 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.021
# 0:00:55.246432 delay=1 neuron=40 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.019
# 0:00:55.122504 delay=1 neuron=40 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.025
# 0:00:55.290409 delay=1 neuron=40 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.020
# 0:00:55.403343 delay=1 neuron=40 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.024
# 0:00:56.624646 delay=1 neuron=45 btch_sz=100 drpout=0.1 train_mse=0.028 test_mse=0.018
# 0:00:56.064965 delay=1 neuron=45 btch_sz=100 drpout=0.2 train_mse=0.027 test_mse=0.019
# 0:00:56.088951 delay=1 neuron=45 btch_sz=100 drpout=0.3 train_mse=0.025 test_mse=0.022
# 0:00:55.994006 delay=1 neuron=45 btch_sz=125 drpout=0.1 train_mse=0.028 test_mse=0.015
# 0:00:56.221876 delay=1 neuron=45 btch_sz=125 drpout=0.2 train_mse=0.028 test_mse=0.016
# 0:00:56.324816 delay=1 neuron=45 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.019
# 0:00:56.297833 delay=1 neuron=45 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.021
# 0:00:56.292837 delay=1 neuron=45 btch_sz=150 drpout=0.2 train_mse=0.029 test_mse=0.014
# 0:00:56.344806 delay=1 neuron=45 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.025
# 0:00:57.693037 delay=1 neuron=50 btch_sz=100 drpout=0.1 train_mse=0.026 test_mse=0.019
# 0:00:58.089810 delay=1 neuron=50 btch_sz=100 drpout=0.2 train_mse=0.029 test_mse=0.018
# 0:00:58.287696 delay=1 neuron=50 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.027
# 0:00:57.931899 delay=1 neuron=50 btch_sz=125 drpout=0.1 train_mse=0.030 test_mse=0.014
# 0:00:57.705027 delay=1 neuron=50 btch_sz=125 drpout=0.2 train_mse=0.026 test_mse=0.016
# 0:00:57.378215 delay=1 neuron=50 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.024
# 0:00:57.711024 delay=1 neuron=50 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.020
# 0:00:57.436182 delay=1 neuron=50 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.021
# 0:00:57.572105 delay=1 neuron=50 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.025
# 0:00:49.516707 delay=2 neuron=20 btch_sz=100 drpout=0.1 train_mse=0.026 test_mse=0.021
# 0:00:49.961453 delay=2 neuron=20 btch_sz=100 drpout=0.2 train_mse=0.026 test_mse=0.020
# 0:00:50.084382 delay=2 neuron=20 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.019
# 0:00:49.611652 delay=2 neuron=20 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.020
# 0:00:49.593662 delay=2 neuron=20 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.024
# 0:00:49.576672 delay=2 neuron=20 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.019
# 0:00:49.690608 delay=2 neuron=20 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.022
# 0:00:49.609653 delay=2 neuron=20 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.024
# 0:00:49.692607 delay=2 neuron=20 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.018
# 0:00:50.230299 delay=2 neuron=25 btch_sz=100 drpout=0.1 train_mse=0.025 test_mse=0.022
# 0:00:50.336238 delay=2 neuron=25 btch_sz=100 drpout=0.2 train_mse=0.029 test_mse=0.018
# 0:00:50.365222 delay=2 neuron=25 btch_sz=100 drpout=0.3 train_mse=0.025 test_mse=0.022
# 0:00:50.456169 delay=2 neuron=25 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.020
# 0:00:50.879928 delay=2 neuron=25 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.023
# 0:00:50.716021 delay=2 neuron=25 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.025
# 0:00:50.575103 delay=2 neuron=25 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.026
# 0:00:50.556114 delay=2 neuron=25 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.025
# 0:00:50.448175 delay=2 neuron=25 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.025
# 0:00:51.063822 delay=2 neuron=30 btch_sz=100 drpout=0.1 train_mse=0.025 test_mse=0.024
# 0:00:51.066821 delay=2 neuron=30 btch_sz=100 drpout=0.2 train_mse=0.028 test_mse=0.018
# 0:00:51.180756 delay=2 neuron=30 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.020
# 0:00:51.709454 delay=2 neuron=30 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.018
# 0:00:51.854370 delay=2 neuron=30 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.021
# 0:00:51.116793 delay=2 neuron=30 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.019
# 0:00:51.046833 delay=2 neuron=30 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.027
# 0:00:51.308683 delay=2 neuron=30 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.023
# 0:00:51.071819 delay=2 neuron=30 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.025
# 0:00:53.756284 delay=2 neuron=35 btch_sz=100 drpout=0.1 train_mse=0.025 test_mse=0.022
# 0:00:53.532412 delay=2 neuron=35 btch_sz=100 drpout=0.2 train_mse=0.026 test_mse=0.020
# 0:00:53.578386 delay=2 neuron=35 btch_sz=100 drpout=0.3 train_mse=0.025 test_mse=0.022
# 0:00:53.627357 delay=2 neuron=35 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.020
# 0:00:53.809254 delay=2 neuron=35 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.018
# 0:00:54.229015 delay=2 neuron=35 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.022
# 0:00:54.504857 delay=2 neuron=35 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.019
# 0:00:54.413909 delay=2 neuron=35 btch_sz=150 drpout=0.2 train_mse=0.025 test_mse=0.028
# 0:00:53.908198 delay=2 neuron=35 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.018
# 0:00:54.955599 delay=2 neuron=40 btch_sz=100 drpout=0.1 train_mse=0.025 test_mse=0.025
# 0:00:54.812681 delay=2 neuron=40 btch_sz=100 drpout=0.2 train_mse=0.025 test_mse=0.026
# 0:00:55.126501 delay=2 neuron=40 btch_sz=100 drpout=0.3 train_mse=0.025 test_mse=0.023
# 0:00:54.751716 delay=2 neuron=40 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.019
# 0:00:55.079529 delay=2 neuron=40 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.019
# 0:00:55.365365 delay=2 neuron=40 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.019
# 0:00:54.928616 delay=2 neuron=40 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.025
# 0:00:55.227444 delay=2 neuron=40 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.020
# 0:00:55.210453 delay=2 neuron=40 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.024
# 0:00:55.927044 delay=2 neuron=45 btch_sz=100 drpout=0.1 train_mse=0.025 test_mse=0.021
# 0:00:55.852087 delay=2 neuron=45 btch_sz=100 drpout=0.2 train_mse=0.026 test_mse=0.019
# 0:00:56.050974 delay=2 neuron=45 btch_sz=100 drpout=0.3 train_mse=0.029 test_mse=0.018
# 0:00:55.871076 delay=2 neuron=45 btch_sz=125 drpout=0.1 train_mse=0.027 test_mse=0.015
# 0:00:56.522705 delay=2 neuron=45 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.017
# 0:00:56.257857 delay=2 neuron=45 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.019
# 0:00:56.488724 delay=2 neuron=45 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.016
# 0:00:56.795549 delay=2 neuron=45 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.022
# 0:00:56.633641 delay=2 neuron=45 btch_sz=150 drpout=0.3 train_mse=0.023 test_mse=0.020
# 0:00:57.517136 delay=2 neuron=50 btch_sz=100 drpout=0.1 train_mse=0.034 test_mse=0.016
# 0:00:57.717021 delay=2 neuron=50 btch_sz=100 drpout=0.2 train_mse=0.027 test_mse=0.018
# 0:00:57.365223 delay=2 neuron=50 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.018
# 0:00:57.311254 delay=2 neuron=50 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.022
# 0:00:57.334241 delay=2 neuron=50 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.021
# 0:00:57.292264 delay=2 neuron=50 btch_sz=125 drpout=0.3 train_mse=0.026 test_mse=0.018
# 0:00:57.921904 delay=2 neuron=50 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.020
# 0:00:57.260284 delay=2 neuron=50 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.025
# 0:00:57.332242 delay=2 neuron=50 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.022
# 0:00:49.115936 delay=3 neuron=20 btch_sz=100 drpout=0.1 train_mse=0.025 test_mse=0.024
# 0:00:49.240864 delay=3 neuron=20 btch_sz=100 drpout=0.2 train_mse=0.027 test_mse=0.021
# 0:00:49.211880 delay=3 neuron=20 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.019
# 0:00:49.405771 delay=3 neuron=20 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.018
# 0:00:49.364794 delay=3 neuron=20 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.018
# 0:00:49.330814 delay=3 neuron=20 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.019
# 0:00:49.614650 delay=3 neuron=20 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.022
# 0:00:49.554686 delay=3 neuron=20 btch_sz=150 drpout=0.2 train_mse=0.025 test_mse=0.016
# 0:00:49.967450 delay=3 neuron=20 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.020
# 0:00:50.364224 delay=3 neuron=25 btch_sz=100 drpout=0.1 train_mse=0.026 test_mse=0.020
# 0:00:49.963454 delay=3 neuron=25 btch_sz=100 drpout=0.2 train_mse=0.026 test_mse=0.020
# 0:00:49.945463 delay=3 neuron=25 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.021
# 0:00:50.207313 delay=3 neuron=25 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.020
# 0:00:50.193322 delay=3 neuron=25 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.018
# 0:00:50.085381 delay=3 neuron=25 btch_sz=125 drpout=0.3 train_mse=0.027 test_mse=0.030
# 0:00:50.358225 delay=3 neuron=25 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.020
# 0:00:50.514138 delay=3 neuron=25 btch_sz=150 drpout=0.2 train_mse=0.027 test_mse=0.014
# 0:00:50.623075 delay=3 neuron=25 btch_sz=150 drpout=0.3 train_mse=0.024 test_mse=0.019
# 0:00:50.698031 delay=3 neuron=30 btch_sz=100 drpout=0.1 train_mse=0.026 test_mse=0.026
# 0:00:50.747005 delay=3 neuron=30 btch_sz=100 drpout=0.2 train_mse=0.029 test_mse=0.018
# 0:00:50.695034 delay=3 neuron=30 btch_sz=100 drpout=0.3 train_mse=0.025 test_mse=0.022
# 0:00:50.809968 delay=3 neuron=30 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.024
# 0:00:50.669050 delay=3 neuron=30 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.020
# 0:00:50.769991 delay=3 neuron=30 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.020
# 0:00:50.700029 delay=3 neuron=30 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.021
# 0:00:50.895919 delay=3 neuron=30 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.016
# 0:00:50.772988 delay=3 neuron=30 btch_sz=150 drpout=0.3 train_mse=0.025 test_mse=0.016
# 0:00:53.672333 delay=3 neuron=35 btch_sz=100 drpout=0.1 train_mse=0.027 test_mse=0.018
# 0:00:53.754286 delay=3 neuron=35 btch_sz=100 drpout=0.2 train_mse=0.026 test_mse=0.020
# 0:00:53.552401 delay=3 neuron=35 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.018
# 0:00:53.363514 delay=3 neuron=35 btch_sz=125 drpout=0.1 train_mse=0.026 test_mse=0.015
# 0:00:53.462453 delay=3 neuron=35 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.024
# 0:00:53.522418 delay=3 neuron=35 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.018
# 0:00:53.608370 delay=3 neuron=35 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.027
# 0:00:53.487438 delay=3 neuron=35 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.024
# 0:00:53.516421 delay=3 neuron=35 btch_sz=150 drpout=0.3 train_mse=0.025 test_mse=0.016
# 0:00:55.055543 delay=3 neuron=40 btch_sz=100 drpout=0.1 train_mse=0.026 test_mse=0.022
# 0:00:54.569819 delay=3 neuron=40 btch_sz=100 drpout=0.2 train_mse=0.027 test_mse=0.019
# 0:00:54.609797 delay=3 neuron=40 btch_sz=100 drpout=0.3 train_mse=0.025 test_mse=0.022
# 0:00:54.927615 delay=3 neuron=40 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.017
# 0:00:54.685753 delay=3 neuron=40 btch_sz=125 drpout=0.2 train_mse=0.026 test_mse=0.017
# 0:00:54.780699 delay=3 neuron=40 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.020
# 0:00:54.740722 delay=3 neuron=40 btch_sz=150 drpout=0.1 train_mse=0.025 test_mse=0.027
# 0:00:54.846662 delay=3 neuron=40 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.020
# 0:00:54.876646 delay=3 neuron=40 btch_sz=150 drpout=0.3 train_mse=0.025 test_mse=0.016
# 0:00:55.816108 delay=3 neuron=45 btch_sz=100 drpout=0.1 train_mse=0.025 test_mse=0.021
# 0:00:55.979015 delay=3 neuron=45 btch_sz=100 drpout=0.2 train_mse=0.025 test_mse=0.022
# 0:00:56.380786 delay=3 neuron=45 btch_sz=100 drpout=0.3 train_mse=0.026 test_mse=0.024
# 0:00:56.173903 delay=3 neuron=45 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.020
# 0:00:55.937039 delay=3 neuron=45 btch_sz=125 drpout=0.2 train_mse=0.026 test_mse=0.016
# 0:00:56.088951 delay=3 neuron=45 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.017
# 0:00:56.054971 delay=3 neuron=45 btch_sz=150 drpout=0.1 train_mse=0.026 test_mse=0.014
# 0:00:55.939037 delay=3 neuron=45 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.022
# 0:00:55.970019 delay=3 neuron=45 btch_sz=150 drpout=0.3 train_mse=0.025 test_mse=0.017
# 0:00:57.159339 delay=3 neuron=50 btch_sz=100 drpout=0.1 train_mse=0.027 test_mse=0.018
# 0:00:57.701030 delay=3 neuron=50 btch_sz=100 drpout=0.2 train_mse=0.029 test_mse=0.016
# 0:00:57.041407 delay=3 neuron=50 btch_sz=100 drpout=0.3 train_mse=0.027 test_mse=0.019
# 0:00:56.895490 delay=3 neuron=50 btch_sz=125 drpout=0.1 train_mse=0.025 test_mse=0.022
# 0:00:57.178329 delay=3 neuron=50 btch_sz=125 drpout=0.2 train_mse=0.025 test_mse=0.020
# 0:00:56.827530 delay=3 neuron=50 btch_sz=125 drpout=0.3 train_mse=0.025 test_mse=0.016
# 0:00:57.048403 delay=3 neuron=50 btch_sz=150 drpout=0.1 train_mse=0.024 test_mse=0.023
# 0:00:56.870505 delay=3 neuron=50 btch_sz=150 drpout=0.2 train_mse=0.024 test_mse=0.019
# 0:00:57.023419 delay=3 neuron=50 btch_sz=150 drpout=0.3 train_mse=0.023 test_mse=0.021
# 0:00:48.367363 delay=6 neuron=20 btch_sz=100 drpout=0.1 train_mse=0.021 test_mse=0.024
# 0:00:48.451316 delay=6 neuron=20 btch_sz=100 drpout=0.2 train_mse=0.023 test_mse=0.022
# 0:00:48.836096 delay=6 neuron=20 btch_sz=100 drpout=0.3 train_mse=0.023 test_mse=0.020
# 0:00:49.018991 delay=6 neuron=20 btch_sz=125 drpout=0.1 train_mse=0.027 test_mse=0.015
# 0:00:48.792120 delay=6 neuron=20 btch_sz=125 drpout=0.2 train_mse=0.022 test_mse=0.029
# 0:00:48.449317 delay=6 neuron=20 btch_sz=125 drpout=0.3 train_mse=0.021 test_mse=0.026
# 0:00:48.540265 delay=6 neuron=20 btch_sz=150 drpout=0.1 train_mse=0.021 test_mse=0.028
# 0:00:48.570248 delay=6 neuron=20 btch_sz=150 drpout=0.2 train_mse=0.021 test_mse=0.024
# 0:00:48.475301 delay=6 neuron=20 btch_sz=150 drpout=0.3 train_mse=0.022 test_mse=0.022
# 0:00:49.053972 delay=6 neuron=25 btch_sz=100 drpout=0.1 train_mse=0.023 test_mse=0.020
# 0:00:49.267849 delay=6 neuron=25 btch_sz=100 drpout=0.2 train_mse=0.026 test_mse=0.017
# 0:00:49.593663 delay=6 neuron=25 btch_sz=100 drpout=0.3 train_mse=0.023 test_mse=0.020
# 0:00:49.218878 delay=6 neuron=25 btch_sz=125 drpout=0.1 train_mse=0.023 test_mse=0.019
# 0:00:49.299830 delay=6 neuron=25 btch_sz=125 drpout=0.2 train_mse=0.022 test_mse=0.020
# 0:00:49.105949 delay=6 neuron=25 btch_sz=125 drpout=0.3 train_mse=0.022 test_mse=0.019
# 0:00:49.038980 delay=6 neuron=25 btch_sz=150 drpout=0.1 train_mse=0.021 test_mse=0.024
# 0:00:49.409770 delay=6 neuron=25 btch_sz=150 drpout=0.2 train_mse=0.022 test_mse=0.034
# 0:00:49.147918 delay=6 neuron=25 btch_sz=150 drpout=0.3 train_mse=0.021 test_mse=0.020
# 0:00:49.749573 delay=6 neuron=30 btch_sz=100 drpout=0.1 train_mse=0.022 test_mse=0.021
# 0:00:49.802543 delay=6 neuron=30 btch_sz=100 drpout=0.2 train_mse=0.021 test_mse=0.022
# 0:00:49.881498 delay=6 neuron=30 btch_sz=100 drpout=0.3 train_mse=0.021 test_mse=0.029
# 0:00:50.173332 delay=6 neuron=30 btch_sz=125 drpout=0.1 train_mse=0.021 test_mse=0.021
# 0:00:50.524136 delay=6 neuron=30 btch_sz=125 drpout=0.2 train_mse=0.022 test_mse=0.019
# 0:00:50.203313 delay=6 neuron=30 btch_sz=125 drpout=0.3 train_mse=0.022 test_mse=0.020
# 0:00:49.841521 delay=6 neuron=30 btch_sz=150 drpout=0.1 train_mse=0.021 test_mse=0.023
# 0:00:49.866508 delay=6 neuron=30 btch_sz=150 drpout=0.2 train_mse=0.021 test_mse=0.022
# 0:00:49.951461 delay=6 neuron=30 btch_sz=150 drpout=0.3 train_mse=0.021 test_mse=0.032
# 0:00:52.204172 delay=6 neuron=35 btch_sz=100 drpout=0.1 train_mse=0.022 test_mse=0.020
# 0:00:52.578957 delay=6 neuron=35 btch_sz=100 drpout=0.2 train_mse=0.025 test_mse=0.016
# 0:00:52.474018 delay=6 neuron=35 btch_sz=100 drpout=0.3 train_mse=0.022 test_mse=0.019
# 0:00:52.872790 delay=6 neuron=35 btch_sz=125 drpout=0.1 train_mse=0.021 test_mse=0.026
# 0:00:52.561967 delay=6 neuron=35 btch_sz=125 drpout=0.2 train_mse=0.022 test_mse=0.018
# 0:00:52.446033 delay=6 neuron=35 btch_sz=125 drpout=0.3 train_mse=0.022 test_mse=0.021
# 0:00:52.569964 delay=6 neuron=35 btch_sz=150 drpout=0.1 train_mse=0.021 test_mse=0.028
# 0:00:52.716878 delay=6 neuron=35 btch_sz=150 drpout=0.2 train_mse=0.021 test_mse=0.021
# 0:00:52.488009 delay=6 neuron=35 btch_sz=150 drpout=0.3 train_mse=0.020 test_mse=0.026
# 0:00:53.166621 delay=6 neuron=40 btch_sz=100 drpout=0.1 train_mse=0.022 test_mse=0.025
# 0:00:53.361511 delay=6 neuron=40 btch_sz=100 drpout=0.2 train_mse=0.023 test_mse=0.018
# 0:00:53.422476 delay=6 neuron=40 btch_sz=100 drpout=0.3 train_mse=0.023 test_mse=0.020
# 0:00:53.406485 delay=6 neuron=40 btch_sz=125 drpout=0.1 train_mse=0.022 test_mse=0.019
# 0:00:54.001144 delay=6 neuron=40 btch_sz=125 drpout=0.2 train_mse=0.021 test_mse=0.027
# 0:00:53.953173 delay=6 neuron=40 btch_sz=125 drpout=0.3 train_mse=0.021 test_mse=0.024
# 0:00:53.998138 delay=6 neuron=40 btch_sz=150 drpout=0.1 train_mse=0.021 test_mse=0.028
# 0:00:53.821247 delay=6 neuron=40 btch_sz=150 drpout=0.2 train_mse=0.021 test_mse=0.026
# 0:00:53.775275 delay=6 neuron=40 btch_sz=150 drpout=0.3 train_mse=0.021 test_mse=0.026
# 0:00:55.064537 delay=6 neuron=45 btch_sz=100 drpout=0.1 train_mse=0.022 test_mse=0.020
# 0:00:55.114510 delay=6 neuron=45 btch_sz=100 drpout=0.2 train_mse=0.025 test_mse=0.015
# 0:00:55.014566 delay=6 neuron=45 btch_sz=100 drpout=0.3 train_mse=0.021 test_mse=0.022
# 0:00:55.522275 delay=6 neuron=45 btch_sz=125 drpout=0.1 train_mse=0.022 test_mse=0.019
# 0:00:55.318391 delay=6 neuron=45 btch_sz=125 drpout=0.2 train_mse=0.021 test_mse=0.027
# 0:00:55.014567 delay=6 neuron=45 btch_sz=125 drpout=0.3 train_mse=0.021 test_mse=0.030
# 0:00:55.200459 delay=6 neuron=45 btch_sz=150 drpout=0.1 train_mse=0.020 test_mse=0.021
# 0:00:54.905628 delay=6 neuron=45 btch_sz=150 drpout=0.2 train_mse=0.021 test_mse=0.026
# 0:00:55.043550 delay=6 neuron=45 btch_sz=150 drpout=0.3 train_mse=0.021 test_mse=0.031
# 0:00:56.015994 delay=6 neuron=50 btch_sz=100 drpout=0.1 train_mse=0.022 test_mse=0.019
# 0:00:55.981014 delay=6 neuron=50 btch_sz=100 drpout=0.2 train_mse=0.021 test_mse=0.029
# 0:00:56.024988 delay=6 neuron=50 btch_sz=100 drpout=0.3 train_mse=0.021 test_mse=0.022
# 0:00:55.999003 delay=6 neuron=50 btch_sz=125 drpout=0.1 train_mse=0.023 test_mse=0.039
# 0:00:56.024988 delay=6 neuron=50 btch_sz=125 drpout=0.2 train_mse=0.024 test_mse=0.016
# 0:00:56.264851 delay=6 neuron=50 btch_sz=125 drpout=0.3 train_mse=0.022 test_mse=0.019
# 0:00:56.390780 delay=6 neuron=50 btch_sz=150 drpout=0.1 train_mse=0.021 test_mse=0.016
# 0:00:56.275845 delay=6 neuron=50 btch_sz=150 drpout=0.2 train_mse=0.021 test_mse=0.031
# 0:00:56.051973 delay=6 neuron=50 btch_sz=150 drpout=0.3 train_mse=0.021 test_mse=0.032
# 0:00:46.672331 delay=12 neuron=20 btch_sz=100 drpout=0.1 train_mse=0.008 test_mse=0.004
# 0:00:46.621354 delay=12 neuron=20 btch_sz=100 drpout=0.2 train_mse=0.008 test_mse=0.005
# 0:00:46.525416 delay=12 neuron=20 btch_sz=100 drpout=0.3 train_mse=0.008 test_mse=0.004
# 0:00:46.570390 delay=12 neuron=20 btch_sz=125 drpout=0.1 train_mse=0.007 test_mse=0.005
# 0:00:46.625359 delay=12 neuron=20 btch_sz=125 drpout=0.2 train_mse=0.007 test_mse=0.005
# 0:00:46.972161 delay=12 neuron=20 btch_sz=125 drpout=0.3 train_mse=0.008 test_mse=0.004
# 0:00:46.514422 delay=12 neuron=20 btch_sz=150 drpout=0.1 train_mse=0.006 test_mse=0.006
# 0:00:46.602370 delay=12 neuron=20 btch_sz=150 drpout=0.2 train_mse=0.006 test_mse=0.004
# 0:00:46.685325 delay=12 neuron=20 btch_sz=150 drpout=0.3 train_mse=0.006 test_mse=0.004
# 0:00:47.408911 delay=12 neuron=25 btch_sz=100 drpout=0.1 train_mse=0.008 test_mse=0.004
# 0:00:47.313965 delay=12 neuron=25 btch_sz=100 drpout=0.2 train_mse=0.008 test_mse=0.005
# 0:00:47.337951 delay=12 neuron=25 btch_sz=100 drpout=0.3 train_mse=0.008 test_mse=0.004
# 0:00:47.443892 delay=12 neuron=25 btch_sz=125 drpout=0.1 train_mse=0.007 test_mse=0.006
# 0:00:47.420904 delay=12 neuron=25 btch_sz=125 drpout=0.2 train_mse=0.007 test_mse=0.004
# 0:00:47.582812 delay=12 neuron=25 btch_sz=125 drpout=0.3 train_mse=0.008 test_mse=0.008
# 0:00:47.578814 delay=12 neuron=25 btch_sz=150 drpout=0.1 train_mse=0.006 test_mse=0.004
# 0:00:48.001572 delay=12 neuron=25 btch_sz=150 drpout=0.2 train_mse=0.007 test_mse=0.009
# 0:00:47.509854 delay=12 neuron=25 btch_sz=150 drpout=0.3 train_mse=0.006 test_mse=0.005
# 0:00:48.196462 delay=12 neuron=30 btch_sz=100 drpout=0.1 train_mse=0.007 test_mse=0.003
# 0:00:47.908626 delay=12 neuron=30 btch_sz=100 drpout=0.2 train_mse=0.010 test_mse=0.004
# 0:00:47.949602 delay=12 neuron=30 btch_sz=100 drpout=0.3 train_mse=0.008 test_mse=0.004
# 0:00:48.025559 delay=12 neuron=30 btch_sz=125 drpout=0.1 train_mse=0.007 test_mse=0.004
# 0:00:47.969591 delay=12 neuron=30 btch_sz=125 drpout=0.2 train_mse=0.007 test_mse=0.004
# 0:00:48.021561 delay=12 neuron=30 btch_sz=125 drpout=0.3 train_mse=0.007 test_mse=0.005
# 0:00:48.353371 delay=12 neuron=30 btch_sz=150 drpout=0.1 train_mse=0.006 test_mse=0.003
# 0:00:47.966590 delay=12 neuron=30 btch_sz=150 drpout=0.2 train_mse=0.007 test_mse=0.006
# 0:00:48.115507 delay=12 neuron=30 btch_sz=150 drpout=0.3 train_mse=0.006 test_mse=0.003
# 0:00:50.352229 delay=12 neuron=35 btch_sz=100 drpout=0.1 train_mse=0.008 test_mse=0.004
# 0:00:50.428185 delay=12 neuron=35 btch_sz=100 drpout=0.2 train_mse=0.009 test_mse=0.004
# 0:00:50.439180 delay=12 neuron=35 btch_sz=100 drpout=0.3 train_mse=0.007 test_mse=0.003
# 0:00:50.457170 delay=12 neuron=35 btch_sz=125 drpout=0.1 train_mse=0.007 test_mse=0.004
# 0:00:50.650059 delay=12 neuron=35 btch_sz=125 drpout=0.2 train_mse=0.007 test_mse=0.004
# 0:00:50.532126 delay=12 neuron=35 btch_sz=125 drpout=0.3 train_mse=0.006 test_mse=0.003
# 0:00:50.484154 delay=12 neuron=35 btch_sz=150 drpout=0.1 train_mse=0.006 test_mse=0.003
# 0:00:50.606084 delay=12 neuron=35 btch_sz=150 drpout=0.2 train_mse=0.006 test_mse=0.004
# 0:00:50.929899 delay=12 neuron=35 btch_sz=150 drpout=0.3 train_mse=0.006 test_mse=0.003
# 0:00:51.636495 delay=12 neuron=40 btch_sz=100 drpout=0.1 train_mse=0.008 test_mse=0.004
# 0:00:51.607512 delay=12 neuron=40 btch_sz=100 drpout=0.2 train_mse=0.007 test_mse=0.004
# 0:00:51.489579 delay=12 neuron=40 btch_sz=100 drpout=0.3 train_mse=0.007 test_mse=0.004
# 0:00:51.377643 delay=12 neuron=40 btch_sz=125 drpout=0.1 train_mse=0.008 test_mse=0.004
# 0:00:51.564537 delay=12 neuron=40 btch_sz=125 drpout=0.2 train_mse=0.007 test_mse=0.004
# 0:00:51.423617 delay=12 neuron=40 btch_sz=125 drpout=0.3 train_mse=0.008 test_mse=0.004
# 0:00:51.529557 delay=12 neuron=40 btch_sz=150 drpout=0.1 train_mse=0.006 test_mse=0.004
# 0:00:51.976302 delay=12 neuron=40 btch_sz=150 drpout=0.2 train_mse=0.006 test_mse=0.004
# 0:00:51.536552 delay=12 neuron=40 btch_sz=150 drpout=0.3 train_mse=0.006 test_mse=0.003
# 0:00:52.743864 delay=12 neuron=45 btch_sz=100 drpout=0.1 train_mse=0.008 test_mse=0.004
# 0:00:52.635924 delay=12 neuron=45 btch_sz=100 drpout=0.2 train_mse=0.009 test_mse=0.004
# 0:00:52.786839 delay=12 neuron=45 btch_sz=100 drpout=0.3 train_mse=0.009 test_mse=0.004
# 0:00:52.702887 delay=12 neuron=45 btch_sz=125 drpout=0.1 train_mse=0.006 test_mse=0.003
# 0:00:53.098660 delay=12 neuron=45 btch_sz=125 drpout=0.2 train_mse=0.006 test_mse=0.004
# 0:00:52.726873 delay=12 neuron=45 btch_sz=125 drpout=0.3 train_mse=0.008 test_mse=0.003
# 0:00:52.832812 delay=12 neuron=45 btch_sz=150 drpout=0.1 train_mse=0.006 test_mse=0.003
# 0:00:52.842806 delay=12 neuron=45 btch_sz=150 drpout=0.2 train_mse=0.008 test_mse=0.003
# 0:00:54.253001 delay=12 neuron=45 btch_sz=150 drpout=0.3 train_mse=0.006 test_mse=0.003
# 0:00:54.895633 delay=12 neuron=50 btch_sz=100 drpout=0.1 train_mse=0.008 test_mse=0.004
# 0:00:53.868222 delay=12 neuron=50 btch_sz=100 drpout=0.2 train_mse=0.007 test_mse=0.003
# 0:00:53.659340 delay=12 neuron=50 btch_sz=100 drpout=0.3 train_mse=0.007 test_mse=0.004
# 0:00:53.509425 delay=12 neuron=50 btch_sz=125 drpout=0.1 train_mse=0.007 test_mse=0.005
# 0:00:53.686325 delay=12 neuron=50 btch_sz=125 drpout=0.2 train_mse=0.007 test_mse=0.003
# 0:00:53.484441 delay=12 neuron=50 btch_sz=125 drpout=0.3 train_mse=0.007 test_mse=0.004
# 0:00:53.787267 delay=12 neuron=50 btch_sz=150 drpout=0.1 train_mse=0.006 test_mse=0.003
# 0:00:53.593376 delay=12 neuron=50 btch_sz=150 drpout=0.2 train_mse=0.006 test_mse=0.003
# 0:00:54.075104 delay=12 neuron=50 btch_sz=150 drpout=0.3 train_mse=0.006 test_mse=0.005

# %%
t = np.linspace(0, 1, 1024)

#линейная частота сезона
f = 10 #P = 1/10

S1 = np.sin(2*np.pi*2*f*t)
S2 = np.sin(2*np.pi*4*f*t)
S3 = np.sin(2*np.pi*8*f*t)

noise = 0.2*np.random.randn(len(t))

F_lab = S1 + S2 + S3 + noise
F_lab=F_lab.reshape(-1,1)

N = 1024

plt.figure(figsize = (15, 5))
plt.plot(t, F_lab, 'k', label = 'ts')
plt.plot(t, S1, 'b', label = 'S1')
plt.plot(t, S2, 'r', label = 'S2')
plt.plot(t, S3, 'g', label = 'S3')
plt.legend()
plt.show()

# %%
delays=[6,12,15,20]
neurons=[20,25,30,35,40]
batch_sizes=[800,850,900]
dropouts=[0.1,0.2,0.3]

# %%
epochs=100
file_mask=MODELS_DIR+'\\simple_lab_model'
simple_lab_model_result=pd.DataFrame()

# %%
for delay in delays:
    for neuron in neurons:
        for btch_sz in batch_sizes:
            train_mse, test_mse, end=train(F_lab, epochs, file_mask, delay=delay, neuron=neuron, btch_sz=btch_sz)
            simple_lab_model_result=simple_lab_model_result.append([[delay, neuron, btch_sz, train_mse, test_mse, end]], ignore_index=True)
simple_lab_model_result.columns=['delay', 'neuron','btch_sz', 'train_mse', 'test_mse', 'time']
simple_lab_model_result=simple_lab_model_result.sort_values(['test_mse'])
simple_lab_model_result.to_excel('{}_result.xlsx'.format(file_mask), index=None)
# Out:
# 0:02:13.533049 delay=6 neuron=20 btch_sz=800 train_mse=0.004 test_mse=0.003
# 0:02:11.742024 delay=6 neuron=20 btch_sz=850 train_mse=0.005 test_mse=0.004
# 0:02:02.263210 delay=6 neuron=20 btch_sz=900 train_mse=0.005 test_mse=0.005
# 0:02:02.598889 delay=6 neuron=25 btch_sz=800 train_mse=0.004 test_mse=0.004
# 0:02:02.846749 delay=6 neuron=25 btch_sz=850 train_mse=0.004 test_mse=0.004
# 0:02:02.934699 delay=6 neuron=25 btch_sz=900 train_mse=0.004 test_mse=0.004
# 0:02:03.440409 delay=6 neuron=30 btch_sz=800 train_mse=0.004 test_mse=0.003
# 0:02:03.325476 delay=6 neuron=30 btch_sz=850 train_mse=0.004 test_mse=0.004
# 0:02:03.231529 delay=6 neuron=30 btch_sz=900 train_mse=0.004 test_mse=0.003
# 0:02:07.390149 delay=6 neuron=35 btch_sz=800 train_mse=0.004 test_mse=0.003
# 0:02:07.238238 delay=6 neuron=35 btch_sz=850 train_mse=0.004 test_mse=0.004
# 0:02:07.310196 delay=6 neuron=35 btch_sz=900 train_mse=0.004 test_mse=0.003
# 0:02:08.420561 delay=6 neuron=40 btch_sz=800 train_mse=0.004 test_mse=0.003
# 0:02:08.425559 delay=6 neuron=40 btch_sz=850 train_mse=0.004 test_mse=0.004
# 0:02:08.330612 delay=6 neuron=40 btch_sz=900 train_mse=0.004 test_mse=0.003
# 0:02:01.271650 delay=12 neuron=20 btch_sz=800 train_mse=0.003 test_mse=0.002
# 0:02:01.122734 delay=12 neuron=20 btch_sz=850 train_mse=0.002 test_mse=0.003
# 0:02:00.926846 delay=12 neuron=20 btch_sz=900 train_mse=0.002 test_mse=0.002
# 0:02:02.477960 delay=12 neuron=25 btch_sz=800 train_mse=0.003 test_mse=0.002
# 0:02:02.671850 delay=12 neuron=25 btch_sz=850 train_mse=0.003 test_mse=0.003
# 0:02:03.865168 delay=12 neuron=25 btch_sz=900 train_mse=0.002 test_mse=0.002
# 0:02:03.452403 delay=12 neuron=30 btch_sz=800 train_mse=0.004 test_mse=0.003
# 0:02:03.054630 delay=12 neuron=30 btch_sz=850 train_mse=0.003 test_mse=0.002
# 0:02:03.470394 delay=12 neuron=30 btch_sz=900 train_mse=0.003 test_mse=0.003
# 0:02:06.875445 delay=12 neuron=35 btch_sz=800 train_mse=0.002 test_mse=0.002
# 0:02:06.922419 delay=12 neuron=35 btch_sz=850 train_mse=0.002 test_mse=0.002
# 0:02:06.664566 delay=12 neuron=35 btch_sz=900 train_mse=0.003 test_mse=0.002
# 0:02:08.143720 delay=12 neuron=40 btch_sz=800 train_mse=0.003 test_mse=0.003
# 0:02:07.933841 delay=12 neuron=40 btch_sz=850 train_mse=0.003 test_mse=0.003
# 0:02:08.174702 delay=12 neuron=40 btch_sz=900 train_mse=0.003 test_mse=0.003
# 0:02:00.894865 delay=15 neuron=20 btch_sz=800 train_mse=0.003 test_mse=0.003
# 0:02:00.818909 delay=15 neuron=20 btch_sz=850 train_mse=0.003 test_mse=0.003
# 0:02:00.974819 delay=15 neuron=20 btch_sz=900 train_mse=0.002 test_mse=0.002
# 0:02:01.812341 delay=15 neuron=25 btch_sz=800 train_mse=0.003 test_mse=0.003
# 0:02:01.995237 delay=15 neuron=25 btch_sz=850 train_mse=0.002 test_mse=0.002
# 0:02:01.760371 delay=15 neuron=25 btch_sz=900 train_mse=0.002 test_mse=0.003
# 0:02:02.610884 delay=15 neuron=30 btch_sz=800 train_mse=0.002 test_mse=0.002
# 0:02:02.819766 delay=15 neuron=30 btch_sz=850 train_mse=0.002 test_mse=0.002
# 0:02:02.729816 delay=15 neuron=30 btch_sz=900 train_mse=0.002 test_mse=0.002
# 0:02:06.705543 delay=15 neuron=35 btch_sz=800 train_mse=0.002 test_mse=0.002
# 0:02:06.536639 delay=15 neuron=35 btch_sz=850 train_mse=0.002 test_mse=0.002
# 0:02:06.286782 delay=15 neuron=35 btch_sz=900 train_mse=0.002 test_mse=0.002
# 0:02:07.562054 delay=15 neuron=40 btch_sz=800 train_mse=0.002 test_mse=0.002
# 0:02:07.457113 delay=15 neuron=40 btch_sz=850 train_mse=0.003 test_mse=0.003
# 0:02:07.649004 delay=15 neuron=40 btch_sz=900 train_mse=0.003 test_mse=0.003
# 0:01:59.961399 delay=20 neuron=20 btch_sz=800 train_mse=0.002 test_mse=0.002
# 0:02:00.179275 delay=20 neuron=20 btch_sz=850 train_mse=0.002 test_mse=0.002
# 0:02:00.112313 delay=20 neuron=20 btch_sz=900 train_mse=0.002 test_mse=0.002
# 0:02:00.907858 delay=20 neuron=25 btch_sz=800 train_mse=0.002 test_mse=0.002
# 0:02:00.931845 delay=20 neuron=25 btch_sz=850 train_mse=0.002 test_mse=0.002
# 0:02:02.187126 delay=20 neuron=25 btch_sz=900 train_mse=0.002 test_mse=0.002
# 0:02:02.491953 delay=20 neuron=30 btch_sz=800 train_mse=0.002 test_mse=0.002
# 0:02:02.678846 delay=20 neuron=30 btch_sz=850 train_mse=0.002 test_mse=0.002
# 0:02:01.999234 delay=20 neuron=30 btch_sz=900 train_mse=0.002 test_mse=0.002
# 0:02:06.344750 delay=20 neuron=35 btch_sz=800 train_mse=0.002 test_mse=0.002
# 0:02:05.840038 delay=20 neuron=35 btch_sz=850 train_mse=0.002 test_mse=0.002
# 0:02:05.941979 delay=20 neuron=35 btch_sz=900 train_mse=0.002 test_mse=0.002
# 0:02:07.352172 delay=20 neuron=40 btch_sz=800 train_mse=0.002 test_mse=0.002
# 0:02:07.145291 delay=20 neuron=40 btch_sz=850 train_mse=0.002 test_mse=0.002
# 0:02:07.268220 delay=20 neuron=40 btch_sz=900 train_mse=0.002 test_mse=0.002

# %%
epochs=100
file_mask=MODELS_DIR+'\\complex_lab_model'
complex_lab_model_result=pd.DataFrame()

# %%
for delay in delays:
    for neuron in neurons:
        for btch_sz in batch_sizes:
            for drpout in dropouts:
                train_mse, test_mse, end=train(F_lab, epochs, file_mask, delay=delay, neuron=neuron, btch_sz=btch_sz, drpout=drpout)
                complex_lab_model_result=complex_lab_model_result.append([[delay, neuron, btch_sz, drpout, train_mse, test_mse, end]], ignore_index=True)
complex_lab_model_result.columns=['delay', 'neuron','btch_sz', 'drpout', 'train_mse', 'test_mse', 'time']
complex_lab_model_result=complex_lab_model_result.sort_values(['test_mse'])
complex_lab_model_result.to_excel('{}_result.xlsx'.format(file_mask), index=None)
# Out:
# 0:04:45.087972 delay=6 neuron=20 btch_sz=800 drpout=0.1 train_mse=0.004 test_mse=0.004
# 0:04:44.713183 delay=6 neuron=20 btch_sz=800 drpout=0.2 train_mse=0.004 test_mse=0.004
# 0:04:44.496312 delay=6 neuron=20 btch_sz=800 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:04:44.796139 delay=6 neuron=20 btch_sz=850 drpout=0.1 train_mse=0.004 test_mse=0.005
# 0:04:44.706191 delay=6 neuron=20 btch_sz=850 drpout=0.2 train_mse=0.004 test_mse=0.004
# 0:04:44.734174 delay=6 neuron=20 btch_sz=850 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:04:45.603677 delay=6 neuron=20 btch_sz=900 drpout=0.1 train_mse=0.005 test_mse=0.005
# 0:04:46.113386 delay=6 neuron=20 btch_sz=900 drpout=0.2 train_mse=0.004 test_mse=0.005
# 0:04:45.815557 delay=6 neuron=20 btch_sz=900 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:04:48.714899 delay=6 neuron=25 btch_sz=800 drpout=0.1 train_mse=0.004 test_mse=0.004
# 0:04:48.812842 delay=6 neuron=25 btch_sz=800 drpout=0.2 train_mse=0.004 test_mse=0.004
# 0:04:48.850820 delay=6 neuron=25 btch_sz=800 drpout=0.3 train_mse=0.006 test_mse=0.005
# 0:04:48.990740 delay=6 neuron=25 btch_sz=850 drpout=0.1 train_mse=0.004 test_mse=0.004
# 0:04:48.666926 delay=6 neuron=25 btch_sz=850 drpout=0.2 train_mse=0.004 test_mse=0.004
# 0:04:48.982745 delay=6 neuron=25 btch_sz=850 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:04:49.491454 delay=6 neuron=25 btch_sz=900 drpout=0.1 train_mse=0.004 test_mse=0.004
# 0:04:49.683345 delay=6 neuron=25 btch_sz=900 drpout=0.2 train_mse=0.004 test_mse=0.004
# 0:04:49.058702 delay=6 neuron=25 btch_sz=900 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:04:52.250877 delay=6 neuron=30 btch_sz=800 drpout=0.1 train_mse=0.004 test_mse=0.003
# 0:04:52.885513 delay=6 neuron=30 btch_sz=800 drpout=0.2 train_mse=0.004 test_mse=0.003
# 0:04:52.412784 delay=6 neuron=30 btch_sz=800 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:04:53.215325 delay=6 neuron=30 btch_sz=850 drpout=0.1 train_mse=0.004 test_mse=0.004
# 0:04:52.873520 delay=6 neuron=30 btch_sz=850 drpout=0.2 train_mse=0.004 test_mse=0.004
# 0:04:52.796565 delay=6 neuron=30 btch_sz=850 drpout=0.3 train_mse=0.004 test_mse=0.003
# 0:04:51.754161 delay=6 neuron=30 btch_sz=900 drpout=0.1 train_mse=0.004 test_mse=0.004
# 0:04:51.335400 delay=6 neuron=30 btch_sz=900 drpout=0.2 train_mse=0.004 test_mse=0.004
# 0:04:52.465753 delay=6 neuron=30 btch_sz=900 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:05:06.573682 delay=6 neuron=35 btch_sz=800 drpout=0.1 train_mse=0.005 test_mse=0.005
# 0:05:06.346815 delay=6 neuron=35 btch_sz=800 drpout=0.2 train_mse=0.005 test_mse=0.004
# 0:05:06.490726 delay=6 neuron=35 btch_sz=800 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:05:06.582681 delay=6 neuron=35 btch_sz=850 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:05:06.410784 delay=6 neuron=35 btch_sz=850 drpout=0.2 train_mse=0.003 test_mse=0.004
# 0:05:07.175341 delay=6 neuron=35 btch_sz=850 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:05:07.881938 delay=6 neuron=35 btch_sz=900 drpout=0.1 train_mse=0.004 test_mse=0.004
# 0:05:07.309265 delay=6 neuron=35 btch_sz=900 drpout=0.2 train_mse=0.004 test_mse=0.004
# 0:05:07.296273 delay=6 neuron=35 btch_sz=900 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:05:11.732735 delay=6 neuron=40 btch_sz=800 drpout=0.1 train_mse=0.003 test_mse=0.004
# 0:05:11.680766 delay=6 neuron=40 btch_sz=800 drpout=0.2 train_mse=0.004 test_mse=0.003
# 0:05:11.557835 delay=6 neuron=40 btch_sz=800 drpout=0.3 train_mse=0.004 test_mse=0.003
# 0:05:11.601810 delay=6 neuron=40 btch_sz=850 drpout=0.1 train_mse=0.004 test_mse=0.003
# 0:05:11.597813 delay=6 neuron=40 btch_sz=850 drpout=0.2 train_mse=0.004 test_mse=0.004
# 0:05:10.557408 delay=6 neuron=40 btch_sz=850 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:05:10.986163 delay=6 neuron=40 btch_sz=900 drpout=0.1 train_mse=0.004 test_mse=0.004
# 0:05:10.338532 delay=6 neuron=40 btch_sz=900 drpout=0.2 train_mse=0.004 test_mse=0.004
# 0:05:10.624369 delay=6 neuron=40 btch_sz=900 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:04:43.037144 delay=12 neuron=20 btch_sz=800 drpout=0.1 train_mse=0.004 test_mse=0.003
# 0:04:42.989173 delay=12 neuron=20 btch_sz=800 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:43.525866 delay=12 neuron=20 btch_sz=800 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:44.503307 delay=12 neuron=20 btch_sz=850 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:45.658647 delay=12 neuron=20 btch_sz=850 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:44.941058 delay=12 neuron=20 btch_sz=850 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:44.546282 delay=12 neuron=20 btch_sz=900 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:44.021582 delay=12 neuron=20 btch_sz=900 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:44.241457 delay=12 neuron=20 btch_sz=900 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:46.869955 delay=12 neuron=25 btch_sz=800 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:46.655077 delay=12 neuron=25 btch_sz=800 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:46.557132 delay=12 neuron=25 btch_sz=800 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:47.373664 delay=12 neuron=25 btch_sz=850 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:47.560560 delay=12 neuron=25 btch_sz=850 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:48.271153 delay=12 neuron=25 btch_sz=850 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:04:47.439628 delay=12 neuron=25 btch_sz=900 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:47.244740 delay=12 neuron=25 btch_sz=900 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:47.529576 delay=12 neuron=25 btch_sz=900 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:51.049564 delay=12 neuron=30 btch_sz=800 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:51.247451 delay=12 neuron=30 btch_sz=800 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:50.969609 delay=12 neuron=30 btch_sz=800 drpout=0.3 train_mse=0.004 test_mse=0.004
# 0:04:51.270436 delay=12 neuron=30 btch_sz=850 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:51.543282 delay=12 neuron=30 btch_sz=850 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:51.079533 delay=12 neuron=30 btch_sz=850 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:51.138515 delay=12 neuron=30 btch_sz=900 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:51.638227 delay=12 neuron=30 btch_sz=900 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:57.024147 delay=12 neuron=30 btch_sz=900 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:05:04.849671 delay=12 neuron=35 btch_sz=800 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:05:04.504868 delay=12 neuron=35 btch_sz=800 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:05:04.580826 delay=12 neuron=35 btch_sz=800 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:05:05.449329 delay=12 neuron=35 btch_sz=850 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:05:05.458323 delay=12 neuron=35 btch_sz=850 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:05:05.321403 delay=12 neuron=35 btch_sz=850 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:05:05.721173 delay=12 neuron=35 btch_sz=900 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:05:04.887654 delay=12 neuron=35 btch_sz=900 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:05:05.611237 delay=12 neuron=35 btch_sz=900 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:05:09.755868 delay=12 neuron=40 btch_sz=800 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:05:09.962749 delay=12 neuron=40 btch_sz=800 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:05:09.042274 delay=12 neuron=40 btch_sz=800 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:05:08.505582 delay=12 neuron=40 btch_sz=850 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:05:08.492588 delay=12 neuron=40 btch_sz=850 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:05:08.209749 delay=12 neuron=40 btch_sz=850 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:05:08.308694 delay=12 neuron=40 btch_sz=900 drpout=0.1 train_mse=0.003 test_mse=0.002
# 0:05:08.722457 delay=12 neuron=40 btch_sz=900 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:05:08.689475 delay=12 neuron=40 btch_sz=900 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:42.152651 delay=15 neuron=20 btch_sz=800 drpout=0.1 train_mse=0.003 test_mse=0.002
# 0:04:42.440487 delay=15 neuron=20 btch_sz=800 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:42.903222 delay=15 neuron=20 btch_sz=800 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:42.990173 delay=15 neuron=20 btch_sz=850 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:42.777295 delay=15 neuron=20 btch_sz=850 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:42.886231 delay=15 neuron=20 btch_sz=850 drpout=0.3 train_mse=0.002 test_mse=0.003
# 0:04:43.059132 delay=15 neuron=20 btch_sz=900 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:42.849253 delay=15 neuron=20 btch_sz=900 drpout=0.2 train_mse=0.003 test_mse=0.002
# 0:04:42.907220 delay=15 neuron=20 btch_sz=900 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:46.143370 delay=15 neuron=25 btch_sz=800 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:47.006876 delay=15 neuron=25 btch_sz=800 drpout=0.2 train_mse=0.003 test_mse=0.002
# 0:04:47.191769 delay=15 neuron=25 btch_sz=800 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:47.312701 delay=15 neuron=25 btch_sz=850 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:47.143797 delay=15 neuron=25 btch_sz=850 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:47.273725 delay=15 neuron=25 btch_sz=850 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:04:47.078834 delay=15 neuron=25 btch_sz=900 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:47.215756 delay=15 neuron=25 btch_sz=900 drpout=0.2 train_mse=0.003 test_mse=0.002
# 0:04:47.251736 delay=15 neuron=25 btch_sz=900 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:50.008159 delay=15 neuron=30 btch_sz=800 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:49.136656 delay=15 neuron=30 btch_sz=800 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:49.210616 delay=15 neuron=30 btch_sz=800 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:49.514446 delay=15 neuron=30 btch_sz=850 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:49.308559 delay=15 neuron=30 btch_sz=850 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:48.810843 delay=15 neuron=30 btch_sz=850 drpout=0.3 train_mse=0.002 test_mse=0.003
# 0:04:49.914214 delay=15 neuron=30 btch_sz=900 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:04:49.077692 delay=15 neuron=30 btch_sz=900 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:04:49.732318 delay=15 neuron=30 btch_sz=900 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:05:04.284995 delay=15 neuron=35 btch_sz=800 drpout=0.1 train_mse=0.002 test_mse=0.003
# 0:05:05.438337 delay=15 neuron=35 btch_sz=800 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:05:05.069547 delay=15 neuron=35 btch_sz=800 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:05:05.299414 delay=15 neuron=35 btch_sz=850 drpout=0.1 train_mse=0.003 test_mse=0.003
# 0:05:05.195474 delay=15 neuron=35 btch_sz=850 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:05:04.625801 delay=15 neuron=35 btch_sz=850 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:05:05.468318 delay=15 neuron=35 btch_sz=900 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:05:05.245446 delay=15 neuron=35 btch_sz=900 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:05:05.185480 delay=15 neuron=35 btch_sz=900 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:05:08.339676 delay=15 neuron=40 btch_sz=800 drpout=0.1 train_mse=0.002 test_mse=0.003
# 0:05:07.784993 delay=15 neuron=40 btch_sz=800 drpout=0.2 train_mse=0.003 test_mse=0.003
# 0:05:08.026854 delay=15 neuron=40 btch_sz=800 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:05:07.928911 delay=15 neuron=40 btch_sz=850 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:05:08.135793 delay=15 neuron=40 btch_sz=850 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:05:08.160779 delay=15 neuron=40 btch_sz=850 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:05:08.086820 delay=15 neuron=40 btch_sz=900 drpout=0.1 train_mse=0.002 test_mse=0.003
# 0:05:08.102811 delay=15 neuron=40 btch_sz=900 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:05:07.762006 delay=15 neuron=40 btch_sz=900 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:41.638945 delay=20 neuron=20 btch_sz=800 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:41.358105 delay=20 neuron=20 btch_sz=800 drpout=0.2 train_mse=0.004 test_mse=0.003
# 0:04:41.680922 delay=20 neuron=20 btch_sz=800 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:04:42.199624 delay=20 neuron=20 btch_sz=850 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:42.061703 delay=20 neuron=20 btch_sz=850 drpout=0.2 train_mse=0.002 test_mse=0.003
# 0:04:42.409505 delay=20 neuron=20 btch_sz=850 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:04:42.323553 delay=20 neuron=20 btch_sz=900 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:41.310133 delay=20 neuron=20 btch_sz=900 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:42.363531 delay=20 neuron=20 btch_sz=900 drpout=0.3 train_mse=0.003 test_mse=0.003
# 0:04:45.305848 delay=20 neuron=25 btch_sz=800 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:45.048994 delay=20 neuron=25 btch_sz=800 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:44.848110 delay=20 neuron=25 btch_sz=800 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:04:45.058989 delay=20 neuron=25 btch_sz=850 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:45.174924 delay=20 neuron=25 btch_sz=850 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:44.475324 delay=20 neuron=25 btch_sz=850 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:04:49.916782 delay=20 neuron=25 btch_sz=900 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:45.093969 delay=20 neuron=25 btch_sz=900 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:44.663216 delay=20 neuron=25 btch_sz=900 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:04:47.730462 delay=20 neuron=30 btch_sz=800 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:48.745880 delay=20 neuron=30 btch_sz=800 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:48.072267 delay=20 neuron=30 btch_sz=800 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:04:48.589970 delay=20 neuron=30 btch_sz=850 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:48.396077 delay=20 neuron=30 btch_sz=850 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:48.160214 delay=20 neuron=30 btch_sz=850 drpout=0.3 train_mse=0.002 test_mse=0.003
# 0:04:48.583973 delay=20 neuron=30 btch_sz=900 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:49.129662 delay=20 neuron=30 btch_sz=900 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:48.680918 delay=20 neuron=30 btch_sz=900 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:05:04.496874 delay=20 neuron=35 btch_sz=800 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:05:03.897216 delay=20 neuron=35 btch_sz=800 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:05:03.674344 delay=20 neuron=35 btch_sz=800 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:05:04.288992 delay=20 neuron=35 btch_sz=850 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:05:04.081112 delay=20 neuron=35 btch_sz=850 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:05:04.710752 delay=20 neuron=35 btch_sz=850 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:05:03.929203 delay=20 neuron=35 btch_sz=900 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:48.055276 delay=20 neuron=35 btch_sz=900 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:47.977319 delay=20 neuron=35 btch_sz=900 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:04:53.097580 delay=20 neuron=40 btch_sz=800 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:52.874707 delay=20 neuron=40 btch_sz=800 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:54.721460 delay=20 neuron=40 btch_sz=800 drpout=0.3 train_mse=0.002 test_mse=0.003
# 0:04:52.870554 delay=20 neuron=40 btch_sz=850 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:53.138580 delay=20 neuron=40 btch_sz=850 drpout=0.2 train_mse=0.002 test_mse=0.003
# 0:04:52.697990 delay=20 neuron=40 btch_sz=850 drpout=0.3 train_mse=0.002 test_mse=0.002
# 0:04:52.548706 delay=20 neuron=40 btch_sz=900 drpout=0.1 train_mse=0.002 test_mse=0.002
# 0:04:52.387812 delay=20 neuron=40 btch_sz=900 drpout=0.2 train_mse=0.002 test_mse=0.002
# 0:04:52.460967 delay=20 neuron=40 btch_sz=900 drpout=0.3 train_mse=0.002 test_mse=0.002

# %%
F_trendless=Fort.ravel()-[-9.8576*x + 3872.7 for x in range(174)]
F_trendless=F_trendless.reshape(-1,1)

plt.figure(figsize = (15, 5))
plt.plot(F_trendless, 'k')
plt.show()

# %%
delays=[1,2,3,6,12]
neurons=[10,20,25,30,35,40]
batch_sizes=[100,125,150]
dropouts=[0.1,0.2,0.3]

# %%
epochs=100
file_mask=MODELS_DIR+'\\simple_fort_trendless_model'
simple_fort_trendless_model_result=pd.DataFrame()

# %%
for delay in delays:
    for neuron in neurons:
        for btch_sz in batch_sizes:
            train_mse, test_mse, end=train(F_trendless, epochs, file_mask, delay=delay, neuron=neuron, btch_sz=btch_sz)
            simple_fort_trendless_model_result=simple_fort_trendless_model_result.append([[delay, neuron, btch_sz, train_mse, test_mse, end]], ignore_index=True)
simple_fort_trendless_model_result.columns=['delay', 'neuron','btch_sz', 'train_mse', 'test_mse', 'time']
simple_fort_trendless_model_result=simple_fort_trendless_model_result.sort_values(['test_mse'])
simple_fort_trendless_model_result.to_excel('{}_result.xlsx'.format(file_mask), index=None)
# Out:
# 0:00:20.782126 delay=1 neuron=10 btch_sz=100 train_mse=0.044 test_mse=0.030
# 0:00:20.718160 delay=1 neuron=10 btch_sz=125 train_mse=0.041 test_mse=0.025
# 0:00:20.714163 delay=1 neuron=10 btch_sz=150 train_mse=0.038 test_mse=0.023
# 0:00:20.937036 delay=1 neuron=20 btch_sz=100 train_mse=0.042 test_mse=0.028
# 0:00:20.894061 delay=1 neuron=20 btch_sz=125 train_mse=0.041 test_mse=0.024
# 0:00:21.232866 delay=1 neuron=20 btch_sz=150 train_mse=0.038 test_mse=0.023
# 0:00:21.255854 delay=1 neuron=25 btch_sz=100 train_mse=0.042 test_mse=0.028
# 0:00:21.001999 delay=1 neuron=25 btch_sz=125 train_mse=0.041 test_mse=0.024
# 0:00:34.896061 delay=1 neuron=25 btch_sz=150 train_mse=0.038 test_mse=0.024
# 0:00:21.247858 delay=1 neuron=30 btch_sz=100 train_mse=0.042 test_mse=0.028
# 0:00:21.212878 delay=1 neuron=30 btch_sz=125 train_mse=0.040 test_mse=0.024
# 0:00:21.253856 delay=1 neuron=30 btch_sz=150 train_mse=0.038 test_mse=0.023
# 0:00:21.746574 delay=1 neuron=35 btch_sz=100 train_mse=0.042 test_mse=0.029
# 0:00:21.731583 delay=1 neuron=35 btch_sz=125 train_mse=0.041 test_mse=0.025
# 0:00:21.729584 delay=1 neuron=35 btch_sz=150 train_mse=0.038 test_mse=0.024
# 0:00:21.983438 delay=1 neuron=40 btch_sz=100 train_mse=0.042 test_mse=0.028
# 0:00:22.065392 delay=1 neuron=40 btch_sz=125 train_mse=0.040 test_mse=0.024
# 0:00:21.959452 delay=1 neuron=40 btch_sz=150 train_mse=0.038 test_mse=0.024
# 0:00:20.505283 delay=2 neuron=10 btch_sz=100 train_mse=0.041 test_mse=0.027
# 0:00:20.508281 delay=2 neuron=10 btch_sz=125 train_mse=0.040 test_mse=0.023
# 0:00:20.472303 delay=2 neuron=10 btch_sz=150 train_mse=0.037 test_mse=0.023
# 0:00:21.174901 delay=2 neuron=20 btch_sz=100 train_mse=0.041 test_mse=0.027
# 0:00:21.050972 delay=2 neuron=20 btch_sz=125 train_mse=0.040 test_mse=0.024
# 0:00:21.156911 delay=2 neuron=20 btch_sz=150 train_mse=0.037 test_mse=0.023
# 0:00:20.885066 delay=2 neuron=25 btch_sz=100 train_mse=0.044 test_mse=0.030
# 0:00:20.897059 delay=2 neuron=25 btch_sz=125 train_mse=0.041 test_mse=0.024
# 0:00:20.855084 delay=2 neuron=25 btch_sz=150 train_mse=0.037 test_mse=0.023
# 0:00:21.134923 delay=2 neuron=30 btch_sz=100 train_mse=0.042 test_mse=0.028
# 0:00:21.081953 delay=2 neuron=30 btch_sz=125 train_mse=0.040 test_mse=0.024
# 0:00:21.008995 delay=2 neuron=30 btch_sz=150 train_mse=0.039 test_mse=0.024
# 0:00:22.034411 delay=2 neuron=35 btch_sz=100 train_mse=0.042 test_mse=0.027
# 0:00:22.932896 delay=2 neuron=35 btch_sz=125 train_mse=0.041 test_mse=0.024
# 0:00:22.468162 delay=2 neuron=35 btch_sz=150 train_mse=0.037 test_mse=0.023
# 0:00:21.956454 delay=2 neuron=40 btch_sz=100 train_mse=0.042 test_mse=0.028
# 0:00:21.899485 delay=2 neuron=40 btch_sz=125 train_mse=0.040 test_mse=0.023
# 0:00:21.919475 delay=2 neuron=40 btch_sz=150 train_mse=0.038 test_mse=0.023
# 0:00:20.448316 delay=3 neuron=10 btch_sz=100 train_mse=0.042 test_mse=0.027
# 0:00:20.280411 delay=3 neuron=10 btch_sz=125 train_mse=0.040 test_mse=0.023
# 0:00:20.397344 delay=3 neuron=10 btch_sz=150 train_mse=0.039 test_mse=0.024
# 0:00:20.575243 delay=3 neuron=20 btch_sz=100 train_mse=0.043 test_mse=0.027
# 0:00:20.522273 delay=3 neuron=20 btch_sz=125 train_mse=0.040 test_mse=0.023
# 0:00:20.533266 delay=3 neuron=20 btch_sz=150 train_mse=0.038 test_mse=0.023
# 0:00:20.714163 delay=3 neuron=25 btch_sz=100 train_mse=0.043 test_mse=0.027
# 0:00:20.691177 delay=3 neuron=25 btch_sz=125 train_mse=0.042 test_mse=0.024
# 0:00:20.974014 delay=3 neuron=25 btch_sz=150 train_mse=0.038 test_mse=0.023
# 0:00:21.001000 delay=3 neuron=30 btch_sz=100 train_mse=0.042 test_mse=0.027
# 0:00:20.870075 delay=3 neuron=30 btch_sz=125 train_mse=0.041 test_mse=0.023
# 0:00:22.450172 delay=3 neuron=30 btch_sz=150 train_mse=0.038 test_mse=0.023
# 0:00:29.076386 delay=3 neuron=35 btch_sz=100 train_mse=0.042 test_mse=0.027
# 0:00:26.717735 delay=3 neuron=35 btch_sz=125 train_mse=0.040 test_mse=0.023
# 0:00:27.725158 delay=3 neuron=35 btch_sz=150 train_mse=0.038 test_mse=0.023
# 0:00:23.136779 delay=3 neuron=40 btch_sz=100 train_mse=0.042 test_mse=0.027
# 0:00:22.679041 delay=3 neuron=40 btch_sz=125 train_mse=0.041 test_mse=0.024
# 0:00:24.737864 delay=3 neuron=40 btch_sz=150 train_mse=0.038 test_mse=0.022
# 0:00:23.759424 delay=6 neuron=10 btch_sz=100 train_mse=0.032 test_mse=0.022
# 0:00:26.529842 delay=6 neuron=10 btch_sz=125 train_mse=0.031 test_mse=0.020
# 0:00:20.562250 delay=6 neuron=10 btch_sz=150 train_mse=0.030 test_mse=0.020
# 0:00:20.674186 delay=6 neuron=20 btch_sz=100 train_mse=0.033 test_mse=0.022
# 0:00:20.732153 delay=6 neuron=20 btch_sz=125 train_mse=0.033 test_mse=0.020
# 0:00:20.558249 delay=6 neuron=20 btch_sz=150 train_mse=0.030 test_mse=0.020
# 0:00:20.692177 delay=6 neuron=25 btch_sz=100 train_mse=0.031 test_mse=0.022
# 0:00:20.711166 delay=6 neuron=25 btch_sz=125 train_mse=0.030 test_mse=0.019
# 0:00:20.754141 delay=6 neuron=25 btch_sz=150 train_mse=0.029 test_mse=0.020
# 0:00:21.298830 delay=6 neuron=30 btch_sz=100 train_mse=0.034 test_mse=0.023
# 0:00:21.106939 delay=6 neuron=30 btch_sz=125 train_mse=0.037 test_mse=0.023
# 0:00:21.023988 delay=6 neuron=30 btch_sz=150 train_mse=0.029 test_mse=0.020
# 0:00:21.696602 delay=6 neuron=35 btch_sz=100 train_mse=0.030 test_mse=0.022
# 0:00:21.748574 delay=6 neuron=35 btch_sz=125 train_mse=0.032 test_mse=0.019
# 0:00:21.669618 delay=6 neuron=35 btch_sz=150 train_mse=0.034 test_mse=0.024
# 0:00:21.930469 delay=6 neuron=40 btch_sz=100 train_mse=0.032 test_mse=0.022
# 0:00:21.966448 delay=6 neuron=40 btch_sz=125 train_mse=0.030 test_mse=0.019
# 0:00:21.942463 delay=6 neuron=40 btch_sz=150 train_mse=0.028 test_mse=0.020
# 0:00:19.692749 delay=12 neuron=10 btch_sz=100 train_mse=0.015 test_mse=0.008
# 0:00:19.608795 delay=12 neuron=10 btch_sz=125 train_mse=0.011 test_mse=0.005
# 0:00:19.643776 delay=12 neuron=10 btch_sz=150 train_mse=0.011 test_mse=0.005
# 0:00:19.834666 delay=12 neuron=20 btch_sz=100 train_mse=0.013 test_mse=0.006
# 0:00:19.767704 delay=12 neuron=20 btch_sz=125 train_mse=0.011 test_mse=0.006
# 0:00:19.810689 delay=12 neuron=20 btch_sz=150 train_mse=0.011 test_mse=0.006
# 0:00:20.406340 delay=12 neuron=25 btch_sz=100 train_mse=0.012 test_mse=0.005
# 0:00:20.029555 delay=12 neuron=25 btch_sz=125 train_mse=0.010 test_mse=0.005
# 0:00:20.040548 delay=12 neuron=25 btch_sz=150 train_mse=0.011 test_mse=0.006
# 0:00:20.219446 delay=12 neuron=30 btch_sz=100 train_mse=0.012 test_mse=0.005
# 0:00:20.245431 delay=12 neuron=30 btch_sz=125 train_mse=0.014 test_mse=0.009
# 0:00:20.210451 delay=12 neuron=30 btch_sz=150 train_mse=0.009 test_mse=0.005
# 0:00:20.949030 delay=12 neuron=35 btch_sz=100 train_mse=0.012 test_mse=0.005
# 0:00:21.176900 delay=12 neuron=35 btch_sz=125 train_mse=0.011 test_mse=0.006
# 0:00:21.150915 delay=12 neuron=35 btch_sz=150 train_mse=0.010 test_mse=0.005
# 0:00:21.445747 delay=12 neuron=40 btch_sz=100 train_mse=0.013 test_mse=0.006
# 0:00:21.103941 delay=12 neuron=40 btch_sz=125 train_mse=0.011 test_mse=0.005
# 0:00:21.111936 delay=12 neuron=40 btch_sz=150 train_mse=0.010 test_mse=0.005

# %%
epochs=100
file_mask=MODELS_DIR+'\\complex_fort_trendless_model'
complex_fort_trendless_model_result=pd.DataFrame()

# %%
for delay in delays:
    for neuron in neurons:
        for btch_sz in batch_sizes:
            for drpout in dropouts:
                train_mse, test_mse, end=train(F_trendless, epochs, file_mask, delay=delay, neuron=neuron, btch_sz=btch_sz, drpout=drpout)
                complex_fort_trendless_model_result=complex_fort_trendless_model_result.append([[delay, neuron, btch_sz, drpout, train_mse, test_mse, end]], ignore_index=True)
complex_fort_trendless_model_result.columns=['delay', 'neuron','btch_sz', 'drpout', 'train_mse', 'test_mse', 'time']
complex_fort_trendless_model_result=complex_fort_trendless_model_result.sort_values(['test_mse'])
complex_fort_trendless_model_result.to_excel('{}_result.xlsx'.format(file_mask), index=None)
# Out:
# 0:00:49.593663 delay=1 neuron=10 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.028
# 0:00:49.843521 delay=1 neuron=10 btch_sz=100 drpout=0.2 train_mse=0.041 test_mse=0.027
# 0:00:49.641635 delay=1 neuron=10 btch_sz=100 drpout=0.3 train_mse=0.042 test_mse=0.028
# 0:00:49.791550 delay=1 neuron=10 btch_sz=125 drpout=0.1 train_mse=0.041 test_mse=0.025
# 0:00:49.781555 delay=1 neuron=10 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.024
# 0:00:49.973446 delay=1 neuron=10 btch_sz=125 drpout=0.3 train_mse=0.040 test_mse=0.024
# 0:00:49.734582 delay=1 neuron=10 btch_sz=150 drpout=0.1 train_mse=0.037 test_mse=0.023
# 0:00:50.149346 delay=1 neuron=10 btch_sz=150 drpout=0.2 train_mse=0.038 test_mse=0.024
# 0:00:49.713595 delay=1 neuron=10 btch_sz=150 drpout=0.3 train_mse=0.038 test_mse=0.024
# 0:00:51.031842 delay=1 neuron=20 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.028
# 0:00:51.227729 delay=1 neuron=20 btch_sz=100 drpout=0.2 train_mse=0.042 test_mse=0.029
# 0:00:51.047832 delay=1 neuron=20 btch_sz=100 drpout=0.3 train_mse=0.042 test_mse=0.028
# 0:00:51.049832 delay=1 neuron=20 btch_sz=125 drpout=0.1 train_mse=0.040 test_mse=0.024
# 0:00:51.284697 delay=1 neuron=20 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.023
# 0:00:51.052830 delay=1 neuron=20 btch_sz=125 drpout=0.3 train_mse=0.041 test_mse=0.025
# 0:00:50.990865 delay=1 neuron=20 btch_sz=150 drpout=0.1 train_mse=0.038 test_mse=0.023
# 0:00:50.928900 delay=1 neuron=20 btch_sz=150 drpout=0.2 train_mse=0.038 test_mse=0.023
# 0:00:50.936895 delay=1 neuron=20 btch_sz=150 drpout=0.3 train_mse=0.039 test_mse=0.025
# 0:00:51.806399 delay=1 neuron=25 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.028
# 0:00:52.138209 delay=1 neuron=25 btch_sz=100 drpout=0.2 train_mse=0.043 test_mse=0.029
# 0:00:51.736439 delay=1 neuron=25 btch_sz=100 drpout=0.3 train_mse=0.041 test_mse=0.027
# 0:00:51.695461 delay=1 neuron=25 btch_sz=125 drpout=0.1 train_mse=0.040 test_mse=0.024
# 0:00:51.741435 delay=1 neuron=25 btch_sz=125 drpout=0.2 train_mse=0.041 test_mse=0.025
# 0:00:51.713451 delay=1 neuron=25 btch_sz=125 drpout=0.3 train_mse=0.041 test_mse=0.025
# 0:00:52.329099 delay=1 neuron=25 btch_sz=150 drpout=0.1 train_mse=0.038 test_mse=0.023
# 0:00:51.843377 delay=1 neuron=25 btch_sz=150 drpout=0.2 train_mse=0.043 test_mse=0.028
# 0:00:51.553543 delay=1 neuron=25 btch_sz=150 drpout=0.3 train_mse=0.038 test_mse=0.023
# 0:00:52.432041 delay=1 neuron=30 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.028
# 0:00:52.403058 delay=1 neuron=30 btch_sz=100 drpout=0.2 train_mse=0.042 test_mse=0.028
# 0:00:52.416051 delay=1 neuron=30 btch_sz=100 drpout=0.3 train_mse=0.041 test_mse=0.028
# 0:00:52.428043 delay=1 neuron=30 btch_sz=125 drpout=0.1 train_mse=0.040 test_mse=0.024
# 0:00:52.652914 delay=1 neuron=30 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.024
# 0:00:52.493007 delay=1 neuron=30 btch_sz=125 drpout=0.3 train_mse=0.041 test_mse=0.024
# 0:00:52.452030 delay=1 neuron=30 btch_sz=150 drpout=0.1 train_mse=0.038 test_mse=0.023
# 0:00:52.454028 delay=1 neuron=30 btch_sz=150 drpout=0.2 train_mse=0.038 test_mse=0.023
# 0:00:52.481013 delay=1 neuron=30 btch_sz=150 drpout=0.3 train_mse=0.038 test_mse=0.023
# 0:00:55.306400 delay=1 neuron=35 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.028
# 0:00:55.679186 delay=1 neuron=35 btch_sz=100 drpout=0.2 train_mse=0.042 test_mse=0.028
# 0:00:55.244434 delay=1 neuron=35 btch_sz=100 drpout=0.3 train_mse=0.041 test_mse=0.027
# 0:00:55.221446 delay=1 neuron=35 btch_sz=125 drpout=0.1 train_mse=0.040 test_mse=0.024
# 0:00:55.285412 delay=1 neuron=35 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.024
# 0:00:55.270420 delay=1 neuron=35 btch_sz=125 drpout=0.3 train_mse=0.040 test_mse=0.024
# 0:00:55.458312 delay=1 neuron=35 btch_sz=150 drpout=0.1 train_mse=0.037 test_mse=0.023
# 0:00:55.155485 delay=1 neuron=35 btch_sz=150 drpout=0.2 train_mse=0.037 test_mse=0.022
# 0:00:54.947604 delay=1 neuron=35 btch_sz=150 drpout=0.3 train_mse=0.037 test_mse=0.023
# 0:00:55.755143 delay=1 neuron=40 btch_sz=100 drpout=0.1 train_mse=0.041 test_mse=0.028
# 0:00:55.766136 delay=1 neuron=40 btch_sz=100 drpout=0.2 train_mse=0.041 test_mse=0.028
# 0:00:55.827102 delay=1 neuron=40 btch_sz=100 drpout=0.3 train_mse=0.041 test_mse=0.027
# 0:00:55.964021 delay=1 neuron=40 btch_sz=125 drpout=0.1 train_mse=0.041 test_mse=0.025
# 0:00:55.686181 delay=1 neuron=40 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.024
# 0:00:55.803116 delay=1 neuron=40 btch_sz=125 drpout=0.3 train_mse=0.041 test_mse=0.024
# 0:00:55.801116 delay=1 neuron=40 btch_sz=150 drpout=0.1 train_mse=0.038 test_mse=0.023
# 0:00:55.814108 delay=1 neuron=40 btch_sz=150 drpout=0.2 train_mse=0.038 test_mse=0.024
# 0:00:56.237867 delay=1 neuron=40 btch_sz=150 drpout=0.3 train_mse=0.038 test_mse=0.025
# 0:00:49.418763 delay=2 neuron=10 btch_sz=100 drpout=0.1 train_mse=0.043 test_mse=0.029
# 0:00:49.336820 delay=2 neuron=10 btch_sz=100 drpout=0.2 train_mse=0.042 test_mse=0.027
# 0:00:49.406770 delay=2 neuron=10 btch_sz=100 drpout=0.3 train_mse=0.041 test_mse=0.027
# 0:00:49.345804 delay=2 neuron=10 btch_sz=125 drpout=0.1 train_mse=0.041 test_mse=0.024
# 0:00:49.550688 delay=2 neuron=10 btch_sz=125 drpout=0.2 train_mse=0.041 test_mse=0.024
# 0:00:49.591664 delay=2 neuron=10 btch_sz=125 drpout=0.3 train_mse=0.041 test_mse=0.024
# 0:00:49.406769 delay=2 neuron=10 btch_sz=150 drpout=0.1 train_mse=0.039 test_mse=0.024
# 0:00:49.365794 delay=2 neuron=10 btch_sz=150 drpout=0.2 train_mse=0.038 test_mse=0.023
# 0:00:49.415764 delay=2 neuron=10 btch_sz=150 drpout=0.3 train_mse=0.038 test_mse=0.023
# 0:00:50.444176 delay=2 neuron=20 btch_sz=100 drpout=0.1 train_mse=0.041 test_mse=0.027
# 0:00:50.418191 delay=2 neuron=20 btch_sz=100 drpout=0.2 train_mse=0.044 test_mse=0.030
# 0:00:50.521133 delay=2 neuron=20 btch_sz=100 drpout=0.3 train_mse=0.042 test_mse=0.028
# 0:00:50.683040 delay=2 neuron=20 btch_sz=125 drpout=0.1 train_mse=0.043 test_mse=0.026
# 0:00:50.404200 delay=2 neuron=20 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.023
# 0:00:50.463166 delay=2 neuron=20 btch_sz=125 drpout=0.3 train_mse=0.040 test_mse=0.023
# 0:00:50.515131 delay=2 neuron=20 btch_sz=150 drpout=0.1 train_mse=0.038 test_mse=0.023
# 0:00:50.518135 delay=2 neuron=20 btch_sz=150 drpout=0.2 train_mse=0.038 test_mse=0.023
# 0:00:50.365223 delay=2 neuron=20 btch_sz=150 drpout=0.3 train_mse=0.038 test_mse=0.024
# 0:00:51.600516 delay=2 neuron=25 btch_sz=100 drpout=0.1 train_mse=0.041 test_mse=0.027
# 0:00:51.225731 delay=2 neuron=25 btch_sz=100 drpout=0.2 train_mse=0.041 test_mse=0.027
# 0:00:51.328671 delay=2 neuron=25 btch_sz=100 drpout=0.3 train_mse=0.041 test_mse=0.027
# 0:00:51.399631 delay=2 neuron=25 btch_sz=125 drpout=0.1 train_mse=0.040 test_mse=0.024
# 0:00:51.316678 delay=2 neuron=25 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.023
# 0:00:51.218735 delay=2 neuron=25 btch_sz=125 drpout=0.3 train_mse=0.040 test_mse=0.024
# 0:00:51.677472 delay=2 neuron=25 btch_sz=150 drpout=0.1 train_mse=0.038 test_mse=0.023
# 0:00:51.931327 delay=2 neuron=25 btch_sz=150 drpout=0.2 train_mse=0.037 test_mse=0.023
# 0:00:51.341664 delay=2 neuron=25 btch_sz=150 drpout=0.3 train_mse=0.037 test_mse=0.022
# 0:00:52.114223 delay=2 neuron=30 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.028
# 0:00:52.125216 delay=2 neuron=30 btch_sz=100 drpout=0.2 train_mse=0.041 test_mse=0.027
# 0:00:52.270134 delay=2 neuron=30 btch_sz=100 drpout=0.3 train_mse=0.041 test_mse=0.027
# 0:00:52.156199 delay=2 neuron=30 btch_sz=125 drpout=0.1 train_mse=0.040 test_mse=0.023
# 0:00:51.942321 delay=2 neuron=30 btch_sz=125 drpout=0.2 train_mse=0.041 test_mse=0.025
# 0:00:52.062253 delay=2 neuron=30 btch_sz=125 drpout=0.3 train_mse=0.040 test_mse=0.024
# 0:00:52.131213 delay=2 neuron=30 btch_sz=150 drpout=0.1 train_mse=0.037 test_mse=0.023
# 0:00:52.106228 delay=2 neuron=30 btch_sz=150 drpout=0.2 train_mse=0.038 test_mse=0.023
# 0:00:52.411052 delay=2 neuron=30 btch_sz=150 drpout=0.3 train_mse=0.037 test_mse=0.022
# 0:00:55.046547 delay=2 neuron=35 btch_sz=100 drpout=0.1 train_mse=0.041 test_mse=0.027
# 0:00:57.125350 delay=2 neuron=35 btch_sz=100 drpout=0.2 train_mse=0.041 test_mse=0.026
# 0:00:55.091522 delay=2 neuron=35 btch_sz=100 drpout=0.3 train_mse=0.041 test_mse=0.027
# 0:00:55.499289 delay=2 neuron=35 btch_sz=125 drpout=0.1 train_mse=0.040 test_mse=0.023
# 0:00:55.396347 delay=2 neuron=35 btch_sz=125 drpout=0.2 train_mse=0.042 test_mse=0.025
# 0:00:55.333384 delay=2 neuron=35 btch_sz=125 drpout=0.3 train_mse=0.040 test_mse=0.023
# 0:00:55.033555 delay=2 neuron=35 btch_sz=150 drpout=0.1 train_mse=0.037 test_mse=0.022
# 0:00:54.966592 delay=2 neuron=35 btch_sz=150 drpout=0.2 train_mse=0.037 test_mse=0.023
# 0:00:55.274417 delay=2 neuron=35 btch_sz=150 drpout=0.3 train_mse=0.037 test_mse=0.022
# 0:00:55.559256 delay=2 neuron=40 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.027
# 0:00:55.797118 delay=2 neuron=40 btch_sz=100 drpout=0.2 train_mse=0.041 test_mse=0.027
# 0:00:55.496291 delay=2 neuron=40 btch_sz=100 drpout=0.3 train_mse=0.041 test_mse=0.027
# 0:00:55.602230 delay=2 neuron=40 btch_sz=125 drpout=0.1 train_mse=0.040 test_mse=0.024
# 0:00:55.549261 delay=2 neuron=40 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.023
# 0:00:55.474303 delay=2 neuron=40 btch_sz=125 drpout=0.3 train_mse=0.040 test_mse=0.024
# 0:00:55.731162 delay=2 neuron=40 btch_sz=150 drpout=0.1 train_mse=0.037 test_mse=0.022
# 0:00:56.032984 delay=2 neuron=40 btch_sz=150 drpout=0.2 train_mse=0.037 test_mse=0.022
# 0:00:55.659198 delay=2 neuron=40 btch_sz=150 drpout=0.3 train_mse=0.037 test_mse=0.022
# 0:00:49.211882 delay=3 neuron=10 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.027
# 0:00:49.113937 delay=3 neuron=10 btch_sz=100 drpout=0.2 train_mse=0.042 test_mse=0.027
# 0:00:48.965018 delay=3 neuron=10 btch_sz=100 drpout=0.3 train_mse=0.043 test_mse=0.027
# 0:00:49.066964 delay=3 neuron=10 btch_sz=125 drpout=0.1 train_mse=0.041 test_mse=0.023
# 0:00:49.447746 delay=3 neuron=10 btch_sz=125 drpout=0.2 train_mse=0.042 test_mse=0.025
# 0:00:49.067963 delay=3 neuron=10 btch_sz=125 drpout=0.3 train_mse=0.041 test_mse=0.024
# 0:00:49.136925 delay=3 neuron=10 btch_sz=150 drpout=0.1 train_mse=0.038 test_mse=0.023
# 0:00:49.163908 delay=3 neuron=10 btch_sz=150 drpout=0.2 train_mse=0.037 test_mse=0.022
# 0:00:49.232870 delay=3 neuron=10 btch_sz=150 drpout=0.3 train_mse=0.038 test_mse=0.024
# 0:00:50.712024 delay=3 neuron=20 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.027
# 0:00:50.386211 delay=3 neuron=20 btch_sz=100 drpout=0.2 train_mse=0.044 test_mse=0.028
# 0:00:50.095375 delay=3 neuron=20 btch_sz=100 drpout=0.3 train_mse=0.042 test_mse=0.026
# 0:00:50.245290 delay=3 neuron=20 btch_sz=125 drpout=0.1 train_mse=0.041 test_mse=0.023
# 0:00:50.131355 delay=3 neuron=20 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.023
# 0:00:50.107368 delay=3 neuron=20 btch_sz=125 drpout=0.3 train_mse=0.040 test_mse=0.023
# 0:00:50.167336 delay=3 neuron=20 btch_sz=150 drpout=0.1 train_mse=0.038 test_mse=0.023
# 0:00:50.501145 delay=3 neuron=20 btch_sz=150 drpout=0.2 train_mse=0.038 test_mse=0.024
# 0:00:50.176330 delay=3 neuron=20 btch_sz=150 drpout=0.3 train_mse=0.037 test_mse=0.022
# 0:00:51.102801 delay=3 neuron=25 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.027
# 0:00:51.120789 delay=3 neuron=25 btch_sz=100 drpout=0.2 train_mse=0.042 test_mse=0.026
# 0:00:51.006855 delay=3 neuron=25 btch_sz=100 drpout=0.3 train_mse=0.042 test_mse=0.027
# 0:00:51.128786 delay=3 neuron=25 btch_sz=125 drpout=0.1 train_mse=0.040 test_mse=0.023
# 0:00:51.188754 delay=3 neuron=25 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.023
# 0:00:51.057826 delay=3 neuron=25 btch_sz=125 drpout=0.3 train_mse=0.040 test_mse=0.023
# 0:00:50.947889 delay=3 neuron=25 btch_sz=150 drpout=0.1 train_mse=0.039 test_mse=0.025
# 0:00:51.088808 delay=3 neuron=25 btch_sz=150 drpout=0.2 train_mse=0.037 test_mse=0.022
# 0:00:51.021846 delay=3 neuron=25 btch_sz=150 drpout=0.3 train_mse=0.038 test_mse=0.022
# 0:00:51.892349 delay=3 neuron=30 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.027
# 0:00:52.712880 delay=3 neuron=30 btch_sz=100 drpout=0.2 train_mse=0.042 test_mse=0.026
# 0:00:51.757426 delay=3 neuron=30 btch_sz=100 drpout=0.3 train_mse=0.042 test_mse=0.027
# 0:00:51.750422 delay=3 neuron=30 btch_sz=125 drpout=0.1 train_mse=0.041 test_mse=0.024
# 0:00:51.759426 delay=3 neuron=30 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.023
# 0:00:51.724445 delay=3 neuron=30 btch_sz=125 drpout=0.3 train_mse=0.040 test_mse=0.023
# 0:00:51.754429 delay=3 neuron=30 btch_sz=150 drpout=0.1 train_mse=0.037 test_mse=0.022
# 0:00:52.009283 delay=3 neuron=30 btch_sz=150 drpout=0.2 train_mse=0.037 test_mse=0.022
# 0:00:51.753429 delay=3 neuron=30 btch_sz=150 drpout=0.3 train_mse=0.039 test_mse=0.025
# 0:00:54.744720 delay=3 neuron=35 btch_sz=100 drpout=0.1 train_mse=0.042 test_mse=0.027
# 0:00:54.666764 delay=3 neuron=35 btch_sz=100 drpout=0.2 train_mse=0.042 test_mse=0.027
# 0:00:54.770706 delay=3 neuron=35 btch_sz=100 drpout=0.3 train_mse=0.042 test_mse=0.027
# 0:00:54.838666 delay=3 neuron=35 btch_sz=125 drpout=0.1 train_mse=0.040 test_mse=0.023
# 0:00:55.058541 delay=3 neuron=35 btch_sz=125 drpout=0.2 train_mse=0.040 test_mse=0.023
# 0:00:54.723732 delay=3 neuron=35 btch_sz=125 drpout=0.3 train_mse=0.041 test_mse=0.023
# 0:00:54.772704 delay=3 neuron=35 btch_sz=150 drpout=0.1 train_mse=0.040 test_mse=0.024
# 0:00:54.487867 delay=3 neuron=35 btch_sz=150 drpout=0.2 train_mse=0.038 test_mse=0.023
# 0:00:54.284982 delay=3 neuron=35 btch_sz=150 drpout=0.3 train_mse=0.038 test_mse=0.023
# 0:00:55.616222 delay=3 neuron=40 btch_sz=100 drpout=0.1 train_mse=0.045 test_mse=0.030
# 0:00:55.711167 delay=3 neuron=40 btch_sz=100 drpout=0.2 train_mse=0.043 test_mse=0.027
# 0:00:55.974017 delay=3 neuron=40 btch_sz=100 drpout=0.3 train_mse=0.043 test_mse=0.027
# 0:00:55.746148 delay=3 neuron=40 btch_sz=125 drpout=0.1 train_mse=0.041 test_mse=0.024
# 0:00:55.201459 delay=3 neuron=40 btch_sz=125 drpout=0.2 train_mse=0.042 test_mse=0.025
# 0:00:55.236438 delay=3 neuron=40 btch_sz=125 drpout=0.3 train_mse=0.041 test_mse=0.023
# 0:00:55.721162 delay=3 neuron=40 btch_sz=150 drpout=0.1 train_mse=0.038 test_mse=0.023
# 0:00:55.533270 delay=3 neuron=40 btch_sz=150 drpout=0.2 train_mse=0.041 test_mse=0.026
# 0:00:55.431327 delay=3 neuron=40 btch_sz=150 drpout=0.3 train_mse=0.037 test_mse=0.023
# 0:00:48.244434 delay=6 neuron=10 btch_sz=100 drpout=0.1 train_mse=0.034 test_mse=0.023
# 0:00:48.201458 delay=6 neuron=10 btch_sz=100 drpout=0.2 train_mse=0.035 test_mse=0.024
# 0:00:48.190465 delay=6 neuron=10 btch_sz=100 drpout=0.3 train_mse=0.035 test_mse=0.024
# 0:00:48.515278 delay=6 neuron=10 btch_sz=125 drpout=0.1 train_mse=0.033 test_mse=0.021
# 0:00:48.141493 delay=6 neuron=10 btch_sz=125 drpout=0.2 train_mse=0.033 test_mse=0.020
# 0:00:48.278415 delay=6 neuron=10 btch_sz=125 drpout=0.3 train_mse=0.034 test_mse=0.021
# 0:00:48.248431 delay=6 neuron=10 btch_sz=150 drpout=0.1 train_mse=0.031 test_mse=0.020
# 0:00:48.066535 delay=6 neuron=10 btch_sz=150 drpout=0.2 train_mse=0.031 test_mse=0.021
# 0:00:48.167479 delay=6 neuron=10 btch_sz=150 drpout=0.3 train_mse=0.032 test_mse=0.022
# 0:00:49.761567 delay=6 neuron=20 btch_sz=100 drpout=0.1 train_mse=0.033 test_mse=0.022
# 0:00:49.311823 delay=6 neuron=20 btch_sz=100 drpout=0.2 train_mse=0.034 test_mse=0.023
# 0:00:49.462737 delay=6 neuron=20 btch_sz=100 drpout=0.3 train_mse=0.034 test_mse=0.022
# 0:00:49.426757 delay=6 neuron=20 btch_sz=125 drpout=0.1 train_mse=0.033 test_mse=0.020
# 0:00:49.999431 delay=6 neuron=20 btch_sz=125 drpout=0.2 train_mse=0.034 test_mse=0.020
# 0:00:49.653629 delay=6 neuron=20 btch_sz=125 drpout=0.3 train_mse=0.036 test_mse=0.022
# 0:00:49.400773 delay=6 neuron=20 btch_sz=150 drpout=0.1 train_mse=0.030 test_mse=0.021
# 0:00:49.420762 delay=6 neuron=20 btch_sz=150 drpout=0.2 train_mse=0.031 test_mse=0.021
# 0:00:49.482726 delay=6 neuron=20 btch_sz=150 drpout=0.3 train_mse=0.030 test_mse=0.020
# 0:00:50.090379 delay=6 neuron=25 btch_sz=100 drpout=0.1 train_mse=0.035 test_mse=0.024
# 0:00:50.207313 delay=6 neuron=25 btch_sz=100 drpout=0.2 train_mse=0.033 test_mse=0.022
# 0:00:50.057398 delay=6 neuron=25 btch_sz=100 drpout=0.3 train_mse=0.033 test_mse=0.023
# 0:00:50.278264 delay=6 neuron=25 btch_sz=125 drpout=0.1 train_mse=0.033 test_mse=0.020
# 0:00:50.331242 delay=6 neuron=25 btch_sz=125 drpout=0.2 train_mse=0.034 test_mse=0.021
# 0:00:52.095233 delay=6 neuron=25 btch_sz=125 drpout=0.3 train_mse=0.034 test_mse=0.020
# 0:00:50.012424 delay=6 neuron=25 btch_sz=150 drpout=0.1 train_mse=0.032 test_mse=0.022
# 0:00:50.068391 delay=6 neuron=25 btch_sz=150 drpout=0.2 train_mse=0.030 test_mse=0.020
# 0:00:50.079385 delay=6 neuron=25 btch_sz=150 drpout=0.3 train_mse=0.031 test_mse=0.021
# 0:00:50.792978 delay=6 neuron=30 btch_sz=100 drpout=0.1 train_mse=0.033 test_mse=0.022
# 0:00:51.080813 delay=6 neuron=30 btch_sz=100 drpout=0.2 train_mse=0.035 test_mse=0.024
# 0:00:51.124788 delay=6 neuron=30 btch_sz=100 drpout=0.3 train_mse=0.033 test_mse=0.022
# 0:00:50.983869 delay=6 neuron=30 btch_sz=125 drpout=0.1 train_mse=0.032 test_mse=0.020
# 0:00:50.982869 delay=6 neuron=30 btch_sz=125 drpout=0.2 train_mse=0.033 test_mse=0.020
# 0:00:50.909910 delay=6 neuron=30 btch_sz=125 drpout=0.3 train_mse=0.034 test_mse=0.020
# 0:00:51.516564 delay=6 neuron=30 btch_sz=150 drpout=0.1 train_mse=0.029 test_mse=0.021
# 0:00:52.320105 delay=6 neuron=30 btch_sz=150 drpout=0.2 train_mse=0.030 test_mse=0.020
# 0:00:50.832955 delay=6 neuron=30 btch_sz=150 drpout=0.3 train_mse=0.030 test_mse=0.020
# 0:00:53.595377 delay=6 neuron=35 btch_sz=100 drpout=0.1 train_mse=0.034 test_mse=0.023
# 0:00:53.567392 delay=6 neuron=35 btch_sz=100 drpout=0.2 train_mse=0.032 test_mse=0.022
# 0:00:53.578386 delay=6 neuron=35 btch_sz=100 drpout=0.3 train_mse=0.033 test_mse=0.022
# 0:00:53.613366 delay=6 neuron=35 btch_sz=125 drpout=0.1 train_mse=0.033 test_mse=0.020
# 0:00:53.990151 delay=6 neuron=35 btch_sz=125 drpout=0.2 train_mse=0.033 test_mse=0.020
# 0:00:53.648347 delay=6 neuron=35 btch_sz=125 drpout=0.3 train_mse=0.033 test_mse=0.020
# 0:00:53.523417 delay=6 neuron=35 btch_sz=150 drpout=0.1 train_mse=0.031 test_mse=0.021
# 0:00:54.452886 delay=6 neuron=35 btch_sz=150 drpout=0.2 train_mse=0.030 test_mse=0.021
# 0:00:55.383355 delay=6 neuron=35 btch_sz=150 drpout=0.3 train_mse=0.033 test_mse=0.023
# 0:00:54.483870 delay=6 neuron=40 btch_sz=100 drpout=0.1 train_mse=0.034 test_mse=0.023
# 0:00:54.178043 delay=6 neuron=40 btch_sz=100 drpout=0.2 train_mse=0.032 test_mse=0.022
# 0:00:54.221018 delay=6 neuron=40 btch_sz=100 drpout=0.3 train_mse=0.033 test_mse=0.023
# 0:00:54.283984 delay=6 neuron=40 btch_sz=125 drpout=0.1 train_mse=0.032 test_mse=0.021
# 0:00:54.170049 delay=6 neuron=40 btch_sz=125 drpout=0.2 train_mse=0.033 test_mse=0.020
# 0:00:54.290980 delay=6 neuron=40 btch_sz=125 drpout=0.3 train_mse=0.033 test_mse=0.019
# 0:00:54.673761 delay=6 neuron=40 btch_sz=150 drpout=0.1 train_mse=0.029 test_mse=0.020
# 0:00:54.836667 delay=6 neuron=40 btch_sz=150 drpout=0.2 train_mse=0.030 test_mse=0.020
# 0:00:54.635782 delay=6 neuron=40 btch_sz=150 drpout=0.3 train_mse=0.030 test_mse=0.020
# 0:00:46.389494 delay=12 neuron=10 btch_sz=100 drpout=0.1 train_mse=0.014 test_mse=0.006
# 0:00:46.255570 delay=12 neuron=10 btch_sz=100 drpout=0.2 train_mse=0.015 test_mse=0.007
# 0:00:46.292550 delay=12 neuron=10 btch_sz=100 drpout=0.3 train_mse=0.017 test_mse=0.010
# 0:00:46.449459 delay=12 neuron=10 btch_sz=125 drpout=0.1 train_mse=0.013 test_mse=0.006
# 0:00:46.365513 delay=12 neuron=10 btch_sz=125 drpout=0.2 train_mse=0.015 test_mse=0.008
# 0:00:46.181612 delay=12 neuron=10 btch_sz=125 drpout=0.3 train_mse=0.013 test_mse=0.007
# 0:00:46.367507 delay=12 neuron=10 btch_sz=150 drpout=0.1 train_mse=0.011 test_mse=0.005
# 0:00:46.263565 delay=12 neuron=10 btch_sz=150 drpout=0.2 train_mse=0.012 test_mse=0.006
# 0:00:46.320533 delay=12 neuron=10 btch_sz=150 drpout=0.3 train_mse=0.014 test_mse=0.007
# 0:00:47.369934 delay=12 neuron=20 btch_sz=100 drpout=0.1 train_mse=0.015 test_mse=0.008
# 0:00:47.636781 delay=12 neuron=20 btch_sz=100 drpout=0.2 train_mse=0.014 test_mse=0.007
# 0:00:47.433896 delay=12 neuron=20 btch_sz=100 drpout=0.3 train_mse=0.014 test_mse=0.006
# 0:00:47.328957 delay=12 neuron=20 btch_sz=125 drpout=0.1 train_mse=0.011 test_mse=0.006
# 0:00:47.429899 delay=12 neuron=20 btch_sz=125 drpout=0.2 train_mse=0.012 test_mse=0.006
# 0:00:47.493863 delay=12 neuron=20 btch_sz=125 drpout=0.3 train_mse=0.012 test_mse=0.006
# 0:00:47.377929 delay=12 neuron=20 btch_sz=150 drpout=0.1 train_mse=0.012 test_mse=0.006
# 0:00:47.677759 delay=12 neuron=20 btch_sz=150 drpout=0.2 train_mse=0.010 test_mse=0.005
# 0:00:47.445890 delay=12 neuron=20 btch_sz=150 drpout=0.3 train_mse=0.011 test_mse=0.006
# 0:00:48.804114 delay=12 neuron=25 btch_sz=100 drpout=0.1 train_mse=0.013 test_mse=0.006
# 0:00:48.118507 delay=12 neuron=25 btch_sz=100 drpout=0.2 train_mse=0.013 test_mse=0.006
# 0:00:48.165479 delay=12 neuron=25 btch_sz=100 drpout=0.3 train_mse=0.014 test_mse=0.006
# 0:00:48.024560 delay=12 neuron=25 btch_sz=125 drpout=0.1 train_mse=0.011 test_mse=0.006
# 0:00:48.343379 delay=12 neuron=25 btch_sz=125 drpout=0.2 train_mse=0.011 test_mse=0.006
# 0:00:48.209453 delay=12 neuron=25 btch_sz=125 drpout=0.3 train_mse=0.014 test_mse=0.008
# 0:00:48.102515 delay=12 neuron=25 btch_sz=150 drpout=0.1 train_mse=0.010 test_mse=0.005
# 0:00:48.059539 delay=12 neuron=25 btch_sz=150 drpout=0.2 train_mse=0.010 test_mse=0.005
# 0:00:48.126501 delay=12 neuron=25 btch_sz=150 drpout=0.3 train_mse=0.011 test_mse=0.005
# 0:00:48.921048 delay=12 neuron=30 btch_sz=100 drpout=0.1 train_mse=0.013 test_mse=0.005
# 0:00:48.841092 delay=12 neuron=30 btch_sz=100 drpout=0.2 train_mse=0.014 test_mse=0.005
# 0:00:49.197889 delay=12 neuron=30 btch_sz=100 drpout=0.3 train_mse=0.014 test_mse=0.006
# 0:00:48.931042 delay=12 neuron=30 btch_sz=125 drpout=0.1 train_mse=0.013 test_mse=0.007
# 0:00:48.799118 delay=12 neuron=30 btch_sz=125 drpout=0.2 train_mse=0.014 test_mse=0.008
# 0:00:48.873074 delay=12 neuron=30 btch_sz=125 drpout=0.3 train_mse=0.012 test_mse=0.005
# 0:00:48.982013 delay=12 neuron=30 btch_sz=150 drpout=0.1 train_mse=0.011 test_mse=0.006
# 0:00:49.039980 delay=12 neuron=30 btch_sz=150 drpout=0.2 train_mse=0.012 test_mse=0.006
# 0:00:49.565679 delay=12 neuron=30 btch_sz=150 drpout=0.3 train_mse=0.011 test_mse=0.005
# 0:00:51.661482 delay=12 neuron=35 btch_sz=100 drpout=0.1 train_mse=0.014 test_mse=0.006
# 0:00:52.138210 delay=12 neuron=35 btch_sz=100 drpout=0.2 train_mse=0.013 test_mse=0.005
# 0:00:51.570533 delay=12 neuron=35 btch_sz=100 drpout=0.3 train_mse=0.012 test_mse=0.006
# 0:00:51.740443 delay=12 neuron=35 btch_sz=125 drpout=0.1 train_mse=0.011 test_mse=0.005
# 0:00:51.658483 delay=12 neuron=35 btch_sz=125 drpout=0.2 train_mse=0.011 test_mse=0.006
# 0:00:52.492006 delay=12 neuron=35 btch_sz=125 drpout=0.3 train_mse=0.012 test_mse=0.006
# 0:00:49.074959 delay=12 neuron=35 btch_sz=150 drpout=0.1 train_mse=0.011 test_mse=0.005
# 0:00:48.626216 delay=12 neuron=35 btch_sz=150 drpout=0.2 train_mse=0.010 test_mse=0.006
# 0:00:48.556256 delay=12 neuron=35 btch_sz=150 drpout=0.3 train_mse=0.011 test_mse=0.006
# 0:00:49.425759 delay=12 neuron=40 btch_sz=100 drpout=0.1 train_mse=0.014 test_mse=0.006
# 0:00:49.429757 delay=12 neuron=40 btch_sz=100 drpout=0.2 train_mse=0.013 test_mse=0.006
# 0:00:50.508140 delay=12 neuron=40 btch_sz=100 drpout=0.3 train_mse=0.014 test_mse=0.006
# 0:00:49.580671 delay=12 neuron=40 btch_sz=125 drpout=0.1 train_mse=0.011 test_mse=0.006
# 0:00:49.675617 delay=12 neuron=40 btch_sz=125 drpout=0.2 train_mse=0.012 test_mse=0.006
# 0:00:49.952457 delay=12 neuron=40 btch_sz=125 drpout=0.3 train_mse=0.011 test_mse=0.005
# 0:00:49.506713 delay=12 neuron=40 btch_sz=150 drpout=0.1 train_mse=0.011 test_mse=0.005
# 0:00:49.471733 delay=12 neuron=40 btch_sz=150 drpout=0.2 train_mse=0.010 test_mse=0.005
# 0:00:49.965451 delay=12 neuron=40 btch_sz=150 drpout=0.3 train_mse=0.010 test_mse=0.005

# %% [markdown]
# # Torch results

# %%
# simple_fort_model_result=pd.read_excel(MODELS_DIR+'\\simple_fort_model_result.xlsx').sort_values(['test_mse'])
# complex_fort_model_result=pd.read_excel(MODELS_DIR+'\\complex_fort_model_result.xlsx').sort_values(['test_mse'])
# simple_lab_model_result=pd.read_excel(MODELS_DIR+'\\simple_lab_model_result.xlsx').sort_values(['test_mse'])
# complex_lab_model_result=pd.read_excel(MODELS_DIR+'\\complex_lab_model_result.xlsx').sort_values(['test_mse'])
# simple_fort_trendless_model_result=pd.read_excel(MODELS_DIR+'\\simple_fort_trendless_model_result.xlsx').sort_values(['test_mse'])
# complex_fort_trendless_model_result=pd.read_excel(MODELS_DIR+'\\complex_fort_trendless_model_result.xlsx').sort_values(['test_mse'])

# %%
simple_fort_model_result.head()
# Out:
#    delay  neuron  btch_sz  train_mse  test_mse      time
# 0     12      40      150   0.005610  0.002398  0.000244
# 1     12      20      150   0.005764  0.002540  0.000229
# 2     12      50      150   0.006020  0.002547  0.000249
# 3     12      35      150   0.005508  0.002550  0.000238
# 4     12      25      150   0.005779  0.002641  0.000228

# %%
complex_fort_model_result.head()
# Out:
#    delay  neuron  btch_sz  drpout  train_mse  test_mse      time
# 0     12      35      150     0.3   0.006103  0.002778  0.000589
# 1     12      45      150     0.1   0.005702  0.003022  0.000611
# 2     12      50      100     0.2   0.007393  0.003079  0.000623
# 3     12      45      150     0.3   0.006180  0.003108  0.000628
# 4     12      40      150     0.3   0.005956  0.003138  0.000596

# %%
simple_lab_model_result.head()
# Out:
#     delay  neuron  btch_sz  train_mse  test_mse            time
# 54     20      35      800   0.001632  0.001583 00:02:06.344750
# 55     20      35      850   0.001700  0.001684 00:02:05.840038
# 48     20      25      800   0.001657  0.001690 00:02:00.907858
# 50     20      25      900   0.001673  0.001704 00:02:02.187126
# 59     20      40      900   0.001733  0.001714 00:02:07.268220

# %%
complex_lab_model_result.head()
# Out:
#      delay  neuron  btch_sz  drpout  train_mse  test_mse            time
# 162     20      35      800     0.1   0.001933  0.001795 00:05:04.496874
# 166     20      35      850     0.2   0.001840  0.001855 00:05:04.081112
# 167     20      35      850     0.3   0.001883  0.001859 00:05:04.710752
# 174     20      40      850     0.1   0.001868  0.001876 00:04:52.870554
# 145     20      25      800     0.2   0.001822  0.001888 00:04:45.048994

# %%
simple_fort_trendless_model_result.head()
# Out:
#    delay  neuron  btch_sz  train_mse  test_mse      time
# 0     12      30      150   0.009422  0.004619  0.000234
# 1     12      35      100   0.011830  0.004901  0.000242
# 2     12      35      150   0.010048  0.005036  0.000245
# 3     12      10      125   0.010525  0.005078  0.000227
# 4     12      25      100   0.011997  0.005204  0.000236

# %%
complex_fort_trendless_model_result.head()
# Out:
#    delay  neuron  btch_sz  drpout  train_mse  test_mse      time
# 0     12      40      150     0.3   0.010023  0.004727  0.000578
# 1     12      40      150     0.1   0.010501  0.004819  0.000573
# 2     12      25      150     0.3   0.010664  0.004906  0.000557
# 3     12      20      150     0.2   0.010461  0.004989  0.000552
# 4     12      25      150     0.1   0.010314  0.005033  0.000557

# %% [markdown]
# ## Fort simple model

# %%
delay=simple_fort_model_result.head(1)['delay'].values[0]
neuron=simple_fort_model_result.head(1)['neuron'].values[0]
train_size=simple_fort_model_result.head(1)['btch_sz'].values[0]

# %%
checkpoint=torch.load(MODELS_DIR+'\\simple_fort_model_{}_{}_{}.t7'.format(delay,neuron,train_size))

net=Net(1, delay, neuron).to(device)
net.load_state_dict(checkpoint['state'])
net.eval()

train_mse = checkpoint['train_mse']
test_mse = checkpoint['test_mse']

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
F_tr, F_test = split_signal(Fort, delay, train_size, scaler, True)
train_xx, train_yy = get_ts(F_tr, delay, train_size)
test_xx, test_yy = get_ts(F_test, delay, train_size)
# Out:
# 150 36

# %%
pred_train=[]
for i in range(len(train_xx)):
    out=net(train_xx[i].unsqueeze(-1).to(device))
    pred_train.append(out.detach().cpu().item())
pred_train=np.array(pred_train)
trainPredict = scaler.inverse_transform(pred_train.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[delay:train_size],trainPredict, 'b')
plt.show()

# %%
pred_test=[]
for i in range(len(test_xx)):
    out=net(test_xx[i].unsqueeze(-1).to(device))
    pred_test.append(out.detach().cpu().item())
pred_test=np.array(pred_test)
testPredict = scaler.inverse_transform(pred_test.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[train_size:len(Fort)],testPredict, 'b')
plt.show()

# %%
pred_forecast=[]
inp=test_xx[-1].unsqueeze(-1).to(device)
for i in range(24):
    out=net(inp)
    out=out.detach().cpu().item()
    pred_forecast.append(out)
    inp[0,0,0]=out
    inp=inp.roll(-1)
pred_forecast=np.array(pred_forecast)
forecastPredict = scaler.inverse_transform(pred_forecast.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[len(Fort)-1:len(Fort)+24-1],forecastPredict, 'b')
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(train_mse, label='train')
plt.plot(test_mse, label='test')
plt.xlabel('epochs')
plt.ylabel('mse')
plt.legend()
plt.show()

# %%
plot_acf(test_yy.ravel()-pred_test, lags = 20)
plt.show()

# %% [markdown]
# ## Fort complex model

# %%
delay=complex_fort_model_result.head(1)['delay'].values[0]
neuron=complex_fort_model_result.head(1)['neuron'].values[0]
train_size=complex_fort_model_result.head(1)['btch_sz'].values[0]
drpout=complex_fort_model_result.head(1)['drpout'].values[0]

# %%
checkpoint=torch.load(MODELS_DIR+'\\complex_fort_model_{}_{}_{}_{}.t7'.format(delay, neuron, train_size, drpout))

net=Net(1, delay, neuron, drpout).to(device)
net.load_state_dict(checkpoint['state'])
net.eval()

train_mse = checkpoint['train_mse']
test_mse = checkpoint['test_mse']

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
F_tr, F_test = split_signal(Fort, delay, train_size, scaler, True)
train_xx, train_yy = get_ts(F_tr, delay, train_size)
test_xx, test_yy = get_ts(F_test, delay, train_size)
# Out:
# 150 36

# %%
pred_train=[]
for i in range(len(train_xx)):
    out=net(train_xx[i].unsqueeze(-1).to(device))
    pred_train.append(out.detach().cpu().item())
pred_train=np.array(pred_train)
trainPredict = scaler.inverse_transform(pred_train.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[delay:train_size],trainPredict, 'b')
plt.show()

# %%
pred_test=[]
for i in range(len(test_xx)):
    out=net(test_xx[i].unsqueeze(-1).to(device))
    pred_test.append(out.detach().cpu().item())
pred_test=np.array(pred_test)
testPredict = scaler.inverse_transform(pred_test.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[train_size:len(Fort)],testPredict, 'b')
plt.show()

# %%
pred_forecast=[]
inp=test_xx[-1].unsqueeze(-1).to(device)
for i in range(24):
    out=net(inp)
    out=out.detach().cpu().item()
    pred_forecast.append(out)
    inp[0,0,0]=out
    inp=inp.roll(-1)
pred_forecast=np.array(pred_forecast)
forecastPredict = scaler.inverse_transform(pred_forecast.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[len(Fort)-1:len(Fort)+24-1],forecastPredict, 'b')
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(train_mse, label='train')
plt.plot(test_mse, label='test')
plt.xlabel('epochs')
plt.ylabel('mse')
plt.legend()
plt.show()

# %%
plot_acf(test_yy.ravel()-pred_test, lags = 20)
plt.show()

# %% [markdown]
# ## Fort trendless simple model

# %%
delay=simple_fort_trendless_model_result.head(1)['delay'].values[0]
neuron=simple_fort_trendless_model_result.head(1)['neuron'].values[0]
train_size=simple_fort_trendless_model_result.head(1)['btch_sz'].values[0]

# %%
checkpoint=torch.load(MODELS_DIR+'\\simple_fort_trendless_model_{}_{}_{}.t7'.format(delay,neuron,train_size))

net=Net(1, delay, neuron).to(device)
net.load_state_dict(checkpoint['state'])
net.eval()

train_mse = checkpoint['train_mse']
test_mse = checkpoint['test_mse']

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
F_tr, F_test = split_signal(F_trendless, delay, train_size, scaler, True)
train_xx, train_yy = get_ts(F_tr, delay, train_size)
test_xx, test_yy = get_ts(F_test, delay, train_size)
# Out:
# 150 36

# %%
pred_train=[]
for i in range(len(train_xx)):
    out=net(train_xx[i].unsqueeze(-1).to(device))
    pred_train.append(out.detach().cpu().item())
pred_train=np.array(pred_train)
trainPredict = scaler.inverse_transform(pred_train.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_trendless, 'k')
plt.plot(np.r_[delay:train_size],trainPredict, 'b')
plt.show()

# %%
pred_test=[]
for i in range(len(test_xx)):
    out=net(test_xx[i].unsqueeze(-1).to(device))
    pred_test.append(out.detach().cpu().item())
pred_test=np.array(pred_test)
testPredict = scaler.inverse_transform(pred_test.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_trendless, 'k')
plt.plot(np.r_[train_size:len(F_trendless)],testPredict, 'b')
plt.show()

# %%
pred_forecast=[]
inp=test_xx[-1].unsqueeze(-1).to(device)
for i in range(24):
    out=net(inp)
    out=out.detach().cpu().item()
    pred_forecast.append(out)
    inp[0,0,0]=out
    inp=inp.roll(-1)
pred_forecast=np.array(pred_forecast)
forecastPredict = scaler.inverse_transform(pred_forecast.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_trendless, 'k')
plt.plot(np.r_[len(F_trendless)-1:len(F_trendless)+24-1],forecastPredict, 'b')
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(train_mse, label='train')
plt.plot(test_mse, label='test')
plt.xlabel('epochs')
plt.ylabel('mse')
plt.legend()
plt.show()

# %%
plot_acf(test_yy.ravel()-pred_test, lags = 20)
plt.show()

# %% [markdown]
# ## Fort trendless complex model

# %%
delay=complex_fort_trendless_model_result.head(1)['delay'].values[0]
neuron=complex_fort_trendless_model_result.head(1)['neuron'].values[0]
train_size=complex_fort_trendless_model_result.head(1)['btch_sz'].values[0]
drpout=complex_fort_trendless_model_result.head(1)['drpout'].values[0]

# %%
checkpoint=torch.load(MODELS_DIR+'\\complex_fort_trendless_model_{}_{}_{}_{}.t7'.format(delay,neuron,train_size,drpout))

net=Net(1, delay, neuron,drpout).to(device)
net.load_state_dict(checkpoint['state'])
net.eval()

train_mse = checkpoint['train_mse']
test_mse = checkpoint['test_mse']

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
F_tr, F_test = split_signal(F_trendless, delay, train_size, scaler, True)
train_xx, train_yy = get_ts(F_tr, delay, train_size)
test_xx, test_yy = get_ts(F_test, delay, train_size)
# Out:
# 150 36

# %%
pred_train=[]
for i in range(len(train_xx)):
    out=net(train_xx[i].unsqueeze(-1).to(device))
    pred_train.append(out.detach().cpu().item())
pred_train=np.array(pred_train)
trainPredict = scaler.inverse_transform(pred_train.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_trendless, 'k')
plt.plot(np.r_[delay:train_size],trainPredict, 'b')
plt.show()

# %%
pred_test=[]
for i in range(len(test_xx)):
    out=net(test_xx[i].unsqueeze(-1).to(device))
    pred_test.append(out.detach().cpu().item())
pred_test=np.array(pred_test)
testPredict = scaler.inverse_transform(pred_test.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_trendless, 'k')
plt.plot(np.r_[train_size:len(F_trendless)],testPredict, 'b')
plt.show()

# %%
pred_forecast=[]
inp=test_xx[-1].unsqueeze(-1).to(device)
for i in range(24):
    out=net(inp)
    out=out.detach().cpu().item()
    pred_forecast.append(out)
    inp[0,0,0]=out
    inp=inp.roll(-1)
pred_forecast=np.array(pred_forecast)
forecastPredict = scaler.inverse_transform(pred_forecast.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_trendless, 'k')
plt.plot(np.r_[len(F_trendless)-1:len(F_trendless)+24-1],forecastPredict, 'b')
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(train_mse, label='train')
plt.plot(test_mse, label='test')
plt.xlabel('epochs')
plt.ylabel('mse')
plt.legend()
plt.show()

# %%
plot_acf(test_yy.ravel()-pred_test, lags = 20)
plt.show()

# %% [markdown]
# ## Lab simple model

# %%
delay=simple_lab_model_result.head(1)['delay'].values[0]
neuron=simple_lab_model_result.head(1)['neuron'].values[0]
train_size=simple_lab_model_result.head(1)['btch_sz'].values[0]

# %%
checkpoint=torch.load(MODELS_DIR+'\\simple_lab_model_{}_{}_{}.t7'.format(delay,neuron,train_size))

net=Net(1, delay, neuron).to(device)
net.load_state_dict(checkpoint['state'])
net.eval()

train_mse = checkpoint['train_mse']
test_mse = checkpoint['test_mse']

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
F_tr, F_test = split_signal(F_lab, delay, train_size, scaler, True)
train_xx, train_yy = get_ts(F_tr, delay, train_size)
test_xx, test_yy = get_ts(F_test, delay, train_size)
# Out:
# 800 244

# %%
pred_train=[]
for i in range(len(train_xx)):
    out=net(train_xx[i].unsqueeze(-1).to(device))
    pred_train.append(out.detach().cpu().item())
pred_train=np.array(pred_train)
trainPredict = scaler.inverse_transform(pred_train.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_lab, 'k')
plt.plot(np.r_[delay:train_size],trainPredict, 'b')
plt.show()

# %%
pred_test=[]
for i in range(len(test_xx)):
    out=net(test_xx[i].unsqueeze(-1).to(device))
    pred_test.append(out.detach().cpu().item())
pred_test=np.array(pred_test)
testPredict = scaler.inverse_transform(pred_test.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_lab, 'k')
plt.plot(np.r_[train_size:len(F_lab)],testPredict, 'b')
plt.show()

# %%
for_forecast=96
pred_forecast=[]
inp=test_xx[-1].unsqueeze(-1).to(device)
for i in range(for_forecast):
    out=net(inp)
    out=out.detach().cpu().item()
    pred_forecast.append(out)
    inp[0,0,0]=out
    inp=inp.roll(-1)
pred_forecast=np.array(pred_forecast)
forecastPredict = scaler.inverse_transform(pred_forecast.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_lab, 'k')
plt.plot(np.r_[len(F_lab)-1:len(F_lab)+for_forecast-1],forecastPredict, 'b')
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(train_mse, label='train')
plt.plot(test_mse, label='test')
plt.xlabel('epochs')
plt.ylabel('mse')
plt.legend()
plt.show()

# %%
plot_acf(test_yy.ravel()-pred_test, lags = 20)
plt.show()

# %% [markdown]
# ## Lab complex model

# %%
delay=complex_lab_model_result.head(1)['delay'].values[0]
neuron=complex_lab_model_result.head(1)['neuron'].values[0]
train_size=complex_lab_model_result.head(1)['btch_sz'].values[0]
drpout=complex_lab_model_result.head(1)['drpout'].values[0]

# %%
checkpoint=torch.load(MODELS_DIR+'\\complex_lab_model_{}_{}_{}_{}.t7'.format(delay,neuron,train_size,drpout))

net=Net(1, delay, neuron, drpout).to(device)
net.load_state_dict(checkpoint['state'])
net.eval()

train_mse = checkpoint['train_mse']
test_mse = checkpoint['test_mse']

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
F_tr, F_test = split_signal(F_lab, delay, train_size, scaler, True)
train_xx, train_yy = get_ts(F_tr, delay, train_size)
test_xx, test_yy = get_ts(F_test, delay, train_size)
# Out:
# 800 244

# %%
pred_train=[]
for i in range(len(train_xx)):
    out=net(train_xx[i].unsqueeze(-1).to(device))
    pred_train.append(out.detach().cpu().item())
pred_train=np.array(pred_train)
trainPredict = scaler.inverse_transform(pred_train.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_lab, 'k')
plt.plot(np.r_[delay:train_size],trainPredict, 'b')
plt.show()

# %%
pred_test=[]
for i in range(len(test_xx)):
    out=net(test_xx[i].unsqueeze(-1).to(device))
    pred_test.append(out.detach().cpu().item())
pred_test=np.array(pred_test)
testPredict = scaler.inverse_transform(pred_test.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_lab, 'k')
plt.plot(np.r_[train_size:len(F_lab)],testPredict, 'b')
plt.show()

# %%
for_forecast=96
pred_forecast=[]
inp=test_xx[-1].unsqueeze(-1).to(device)
for i in range(for_forecast):
    out=net(inp)
    out=out.detach().cpu().item()
    pred_forecast.append(out)
    inp[0,0,0]=out
    inp=inp.roll(-1)
pred_forecast=np.array(pred_forecast)
forecastPredict = scaler.inverse_transform(pred_forecast.reshape(-1,1))
plt.figure(figsize = (10, 5))
plt.plot(F_lab, 'k')
plt.plot(np.r_[len(F_lab)-1:len(F_lab)+for_forecast-1],forecastPredict, 'b')
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(train_mse, label='train')
plt.plot(test_mse, label='test')
plt.xlabel('epochs')
plt.ylabel('mse')
plt.legend()
plt.show()

# %%
plot_acf(test_yy.ravel()-pred_test, lags = 20)
plt.show()

# %% [markdown]
# # Keras

# %%
model = Sequential() # слои соединены последовательно
model.add(LSTM(units=20, input_shape=(1, 6))) # 20 нейронов
model.add(Dense(units = 1)) # выход одномерный
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
plot_model(model, to_file='model.png') # рисунок полученной сети

# %%
model.fit(xx, yy, epochs = 100) # 100 эпох по 144 точки

# %%
trainPredict = model.predict(xx)
trainPredict = scaler.inverse_transform(trainPredict)
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[6:150],trainPredict, 'b')
plt.show()

# %%
testPredict = model.predict(xx_test)
testPredict = scaler.inverse_transform(testPredict)
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[150:174],testPredict, 'b')
plt.show()

# %%
model = Sequential()
model.add(LSTM(units=20, return_sequences=True, input_shape=(1, 6)))
model.add(Dropout(0.2))
model.add(LSTM(units=20, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=20))
model.add(Dense(units = 1))
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
plot_model(model, to_file='model.png')

# %%
model.fit(xx, yy, epochs = 100) # 100 эпох по 144 точки

# %%
trainPredict = model.predict(xx)
trainPredict = scaler.inverse_transform(trainPredict)
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[6:150],trainPredict, 'b')
plt.show()

# %%
testPredict = model.predict(xx_test)
testPredict = scaler.inverse_transform(testPredict)
plt.figure(figsize = (10, 5))
plt.plot(Fort, 'k')
plt.plot(np.r_[150:174],testPredict, 'b')
plt.show()
